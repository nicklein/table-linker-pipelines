# %%
import glob
import time
import os
import pandas as pd
import sklearn.metrics
from sklearn.preprocessing import MinMaxScaler
import pickle
from argparse import ArgumentParser, Namespace
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam
from itertools import chain
from tqdm import tqdm
import copy
import shutil
import pickle

# %% [markdown]
# I assume that the candidate generation and feature genration has already be run on the training and dev tables

# %%
es_url = 'http://ckg07:9200'
es_index = 'wikidatadwd-augmented'

# Input Paths

# GDrive Path: /table-linker-dataset/2019-iswc_challenge_data/t2dv2/canonical-with-context/t2dv2-train-canonical/
train_path = "/home/sriamazingram/USC/Others/ISI/data/t2dv2/t2dv2-train-canonical"

# GDrive Path: /table-linker-dataset/2019-iswc_challenge_data/t2dv2/canonical-with-context/t2dv2-dev-canonical/
dev_path = "/home/sriamazingram/USC/Others/ISI/data/t2dv2/t2dv2-dev-canonical"

# GDrive Path: /table-linker-dataset/2019-iswc_challenge_data/t2dv2/ground_truth/Xinting_GT_csv
ground_truth_files = "/home/sriamazingram/USC/Others/ISI/data/t2dv2/round_1"

# can be downloaded from https://github.com/usc-isi-i2/table-linker-pipelines/blob/main/table-linker-full-pipeline/models/weighted_lr.pkl
classifier_model_path = '/home/sriamazingram/USC/Others/ISI/Repos/table-linker-pipelines/table-linker-full-pipeline/models/weighted_lr.pkl'


# OUTPUT PATHS
output_path = "/home/sriamazingram/USC/Others/ISI/data/t2dv2"
train_output_path = f'{output_path}/train1-output'
dev_output_path = f'{output_path}/dev-output'

# increase version to create a new folder for an experiment
VERSION = "8_1"

train_candidate_path = f'{train_output_path}/{VERSION}/candidates'
train_feature_path = f'{train_output_path}/{VERSION}/features'

dev_candidate_path = f'{dev_output_path}/{VERSION}/candidates'
dev_feature_path = f'{dev_output_path}/{VERSION}/features'
dev_output_predictions = f'{dev_output_path}/{VERSION}/dev_predictions'
dev_predictions_top_k = f'{dev_output_path}/{VERSION}/dev_predictions_top_k'
dev_colorized_path = f'{dev_output_path}/{VERSION}/dev_predictions_colorized'
dev_metrics_path = f'{dev_output_path}/{VERSION}/dev_predictions_metrics'

aux_field = 'graph_embedding_complex,class_count,property_count,context'


train_prop_count = f'{train_output_path}/{VERSION}/train_prop_count' 
train_class_count = f'{train_output_path}/{VERSION}/train_class_count'
train_context_path = f'{train_output_path}/{VERSION}/train_context'
train_graph_embedding = f'{train_output_path}/{VERSION}/train_graph_embedding'

dev_prop_count = f'{dev_output_path}/{VERSION}/dev_prop_count'
dev_class_count = f'{dev_output_path}/{VERSION}/dev_class_count'
dev_context_path = f'{dev_output_path}/{VERSION}/dev_context'
dev_graph_embedding = f'{dev_output_path}/{VERSION}/dev_graph_embedding'

temp_dir = f'{output_path}/temp'

pos_output = f'{temp_dir}/training_data/pos_features.pkl'
neg_output = f'{temp_dir}/training_data/neg_features.pkl'
min_max_scaler_path = f'{temp_dir}/training_data/normalization_factor.pkl'

final_score_column = 'siamese_prediction'

model_save_path = f'{dev_output_path}/{VERSION}/saved_models'
best_model_path = ''

# %%
# !mkdir -p "$temp_dir"

# !mkdir -p "$train_prop_count"
# !mkdir -p "$dev_prop_count"
# !mkdir -p "$train_class_count"
# !mkdir -p "$dev_class_count"
# !mkdir -p "$train_graph_embedding"
# !mkdir -p "$dev_graph_embedding"
# !mkdir -p "$train_context_path"
# !mkdir -p "$dev_context_path"

# !mkdir -p "$train_candidate_path"
# !mkdir -p "$dev_candidate_path"

# !mkdir -p "$train_feature_path"
# !mkdir -p "$dev_feature_path"

# !mkdir -p "$temp_dir/training_data"
# !mkdir -p "$dev_output_predictions"
# !mkdir -p "$model_save_path"
# !mkdir -p "$dev_predictions_top_k"
# !mkdir -p "$dev_colorized_path"
# !mkdir -p "$dev_metrics_path"

# %%
features = ['pagerank','retrieval_score','monge_elkan','monge_elkan_aliases','des_cont_jaccard',
            'jaro_winkler','levenshtein','singleton','num_char','num_tokens',
           'lof_class_count_tf_idf_score', 'lof_property_count_tf_idf_score',
           'lof-graph-embedding-score', 'lof-reciprocal-rank', 'context_score', 'pseudo_gt']

# %%
classifier_features = ['aligned_pagerank', 'smallest_qnode_number', 'monge_elkan', 'des_cont_jaccard_normalized']

# %% [markdown]
# ## Candidate Generation

# %%
def candidate_generation(path, gt_path, output_path, class_count_path, prop_count_path, context_path, graph_embedding):
    file_list = glob.glob(path + '/*.csv')
    for i, file in enumerate(file_list):
        st = time.time()
        filename = file.split('/')[-1]
        print(f"{filename}: {i+1} of {len(file_list)}")
        gt_file = f"{ground_truth_files}/{filename}"
        output_file = f"{output_path}/{filename}"
        
        # !tl clean -c label -o label_clean "$file" / \
        --url $es_url --index $es_index \
        get-fuzzy-augmented-matches -c label_clean \
        --auxiliary-fields {aux_field} \
        --auxiliary-folder "$temp_dir" / \
        --url $es_url --index $es_index \
        get-exact-matches -c label_clean \
        --auxiliary-fields {aux_field} \
        --auxiliary-folder "$temp_dir" / \
        ground-truth-labeler --gt-file "$gt_file" > "$output_file"
        
        for field in aux_field.split(','):
            aux_list = []
            for f in glob.glob(f'{temp_dir}/*{field}.tsv'):
                aux_list.append(pd.read_csv(f, sep='\t', dtype=object))
            aux_df = pd.concat(aux_list).drop_duplicates(subset=['qnode'])
            if field == 'class_count':
                class_count_file = f"{class_count_path}/{filename.strip('.csv')}_class_count.tsv"
                aux_df.to_csv(class_count_file, sep='\t', index=False)
            elif field == 'property_count':
                prop_count_file = f"{prop_count_path}/{filename.strip('.csv')}_prop_count.tsv"
                aux_df.to_csv(prop_count_file, sep='\t', index=False)
            elif field == 'context':
                context_file = f"{context_path}/{filename.strip('.csv')}_context.tsv"
                aux_df.to_csv(context_file, sep='\t', index=False)
            else:
                graph_embedding_file = f"{graph_embedding}/{filename.strip('.csv')}_graph_embedding_complex.tsv"
                aux_df.to_csv(graph_embedding_file, sep='\t', index=False)
        
        print(time.time() - st)

# %%
candidate_generation(train_path, ground_truth_files, train_candidate_path, train_class_count, train_prop_count, train_context_path,train_graph_embedding)
# Out:
# 37856682_0_6818907050314633217.csv: 1 of 44
# clean Time: 0.01623368263244629s
# get-fuzzy-augmented-matches Time: 340.1948094367981s
# get-exact-matches Time: 29.81961441040039s
# ground-truth-labeler Time: 0.8395054340362549s
# 381.86977076530457
# 38428277_0_1311643810102462607.csv: 2 of 44
# clean Time: 0.01183176040649414s
# get-fuzzy-augmented-matches Time: 51.43580222129822s
# get-exact-matches Time: 9.95887541770935s
# ground-truth-labeler Time: 0.21856999397277832s
# 71.64451193809509
# 29414811_12_251152470253168163.csv: 3 of 44
# clean Time: 0.001531362533569336s
# get-fuzzy-augmented-matches Time: 15.03918743133545s
# get-exact-matches Time: 5.983585834503174s
# ground-truth-labeler Time: 0.06758475303649902s
# 25.41498613357544
# 9834884_0_3871985887467090123.csv: 4 of 44
# clean Time: 0.014010906219482422s
# get-fuzzy-augmented-matches Time: 103.59203791618347s
# get-exact-matches Time: 17.642162799835205s
# ground-truth-labeler Time: 0.4782121181488037s
# 129.64985156059265
# 21245481_0_8730460088443117515.csv: 5 of 44
# clean Time: 0.022821426391601562s
# get-fuzzy-augmented-matches Time: 41.01638436317444s
# get-exact-matches Time: 12.657189130783081s
# ground-truth-labeler Time: 0.3700263500213623s
# 60.04527235031128
# 39650055_5_7135804139753401681.csv: 6 of 44
# clean Time: 0.0036475658416748047s
# get-fuzzy-augmented-matches Time: 53.430477142333984s
# get-exact-matches Time: 8.648519277572632s
# ground-truth-labeler Time: 0.22110295295715332s
# 68.35590934753418
# 53989675_0_8697482470743954630.csv: 7 of 44
# clean Time: 0.002081632614135742s
# get-fuzzy-augmented-matches Time: 18.657920837402344s
# get-exact-matches Time: 6.290971279144287s
# ground-truth-labeler Time: 0.0747063159942627s
# 29.30821418762207
# 99070098_0_2074872741302696997.csv: 8 of 44
# clean Time: 0.0069048404693603516s
# get-fuzzy-augmented-matches Time: 57.238909006118774s
# get-exact-matches Time: 8.201977491378784s
# ground-truth-labeler Time: 0.3370826244354248s
# 71.73481845855713
# 46671561_0_6122315295162029872.csv: 9 of 44
# clean Time: 0.006184816360473633s
# get-fuzzy-augmented-matches Time: 65.9597532749176s
# get-exact-matches Time: 10.415182828903198s
# ground-truth-labeler Time: 0.3623495101928711s
# 83.11771512031555
# 80588006_0_6965325215443683359.csv: 10 of 44
# clean Time: 0.004507303237915039s
# get-fuzzy-augmented-matches Time: 11.047236442565918s
# get-exact-matches Time: 2.714442491531372s
# ground-truth-labeler Time: 0.05149102210998535s
# 18.23001790046692
# 20135078_0_7570343137119682530.csv: 11 of 44
# clean Time: 0.013566970825195312s
# get-fuzzy-augmented-matches Time: 41.82964468002319s
# get-exact-matches Time: 8.052527666091919s
# ground-truth-labeler Time: 0.20529866218566895s
# 55.80619788169861
# 39107734_2_2329160387535788734.csv: 12 of 44
# clean Time: 0.002480745315551758s
# get-fuzzy-augmented-matches Time: 19.50891375541687s
# get-exact-matches Time: 5.744201421737671s
# ground-truth-labeler Time: 0.0902400016784668s
# 29.91886878013611
# 58891288_0_1117541047012405958.csv: 13 of 44
# clean Time: 0.0043294429779052734s
# get-fuzzy-augmented-matches Time: 31.10920763015747s
# get-exact-matches Time: 7.065011978149414s
# ground-truth-labeler Time: 0.21326589584350586s
# 44.0892379283905
# 84548468_0_5955155464119382182.csv: 14 of 44
# clean Time: 0.003713369369506836s
# get-fuzzy-augmented-matches Time: 31.478376626968384s
# get-exact-matches Time: 6.40631365776062s
# ground-truth-labeler Time: 0.18863964080810547s
# 43.67449951171875
# 16767252_0_2409448375013995751.csv: 15 of 44
# clean Time: 0.003301382064819336s
# get-fuzzy-augmented-matches Time: 31.99979257583618s
# get-exact-matches Time: 7.926612615585327s
# ground-truth-labeler Time: 0.16238045692443848s
# 45.48568844795227
# 88523363_0_8180214313099580515.csv: 16 of 44
# clean Time: 0.017933130264282227s
# get-fuzzy-augmented-matches Time: 124.9766480922699s
# get-exact-matches Time: 12.12012267112732s
# ground-truth-labeler Time: 0.7221274375915527s
# 146.95949721336365
# 69537082_0_7789694313271016902.csv: 17 of 44
# clean Time: 0.00766444206237793s
# get-fuzzy-augmented-matches Time: 61.51172757148743s
# get-exact-matches Time: 11.40402102470398s
# ground-truth-labeler Time: 0.5675196647644043s
# 82.82233500480652
# 33401079_0_9127583903019856402.csv: 18 of 44
# clean Time: 0.01108241081237793s
# get-fuzzy-augmented-matches Time: 32.74405360221863s
# get-exact-matches Time: 7.150878667831421s
# ground-truth-labeler Time: 0.17134356498718262s
# 45.78191661834717
# 1438042989043_35_20150728002309-00287-ip-10-236-191-2_875026214_2.csv: 19 of 44
# clean Time: 0.007729530334472656s
# get-fuzzy-augmented-matches Time: 7.817462682723999s
# get-exact-matches Time: 1.3508803844451904s
# ground-truth-labeler Time: 0.08156967163085938s
# 13.770080327987671
# 26310680_0_5150772059999313798.csv: 20 of 44
# clean Time: 0.013977289199829102s
# get-fuzzy-augmented-matches Time: 46.02268123626709s
# get-exact-matches Time: 9.580568313598633s
# ground-truth-labeler Time: 0.3784596920013428s
# 65.3867974281311
# 60319454_0_3938426910282115527.csv: 21 of 44
# clean Time: 0.0024623870849609375s
# get-fuzzy-augmented-matches Time: 21.243605852127075s
# get-exact-matches Time: 5.872321367263794s
# ground-truth-labeler Time: 0.10690712928771973s
# 32.28225564956665
# 91959037_0_7907661684242014480.csv: 22 of 44
# clean Time: 0.012869596481323242s
# get-fuzzy-augmented-matches Time: 75.2528977394104s
# get-exact-matches Time: 13.20677924156189s
# ground-truth-labeler Time: 0.5762782096862793s
# 97.05226516723633
# 9567241_0_5666388268510912770.csv: 23 of 44
# clean Time: 0.0014233589172363281s
# get-fuzzy-augmented-matches Time: 13.645854949951172s
# get-exact-matches Time: 1.2356081008911133s
# ground-truth-labeler Time: 0.05051612854003906s
# 19.25860595703125
# 21362676_0_6854186738074119688.csv: 24 of 44
# clean Time: 0.0037577152252197266s
# get-fuzzy-augmented-matches Time: 31.39546251296997s
# get-exact-matches Time: 7.059306859970093s
# ground-truth-labeler Time: 0.21282076835632324s
# 44.28995108604431
# 54719588_0_8417197176086756912.csv: 25 of 44
# clean Time: 0.008424997329711914s
# get-fuzzy-augmented-matches Time: 66.8170006275177s
# get-exact-matches Time: 12.006266593933105s
# ground-truth-labeler Time: 0.4369065761566162s
# 86.69982290267944
# 1438042986423_95_20150728002306-00125-ip-10-236-191-2_88435628_5.csv: 26 of 44
# clean Time: 0.0010581016540527344s
# get-fuzzy-augmented-matches Time: 12.375030517578125s
# get-exact-matches Time: 2.5887839794158936s
# ground-truth-labeler Time: 0.039653778076171875s
# 19.104562759399414
# 43237185_1_3636357855502246981.csv: 27 of 44
# clean Time: 0.004565715789794922s
# get-fuzzy-augmented-matches Time: 13.859556674957275s
# get-exact-matches Time: 2.099520683288574s
# ground-truth-labeler Time: 0.07164573669433594s
# 20.466628551483154
# 29414811_13_8724394428539174350.csv: 28 of 44
# clean Time: 0.001298666000366211s
# get-fuzzy-augmented-matches Time: 5.825110673904419s
# get-exact-matches Time: 0.9544405937194824s
# ground-truth-labeler Time: 0.05026841163635254s
# 11.005264282226562
# 53822652_0_5767892317858575530.csv: 29 of 44
# clean Time: 0.013087272644042969s
# get-fuzzy-augmented-matches Time: 118.9392683506012s
# get-exact-matches Time: 12.98902702331543s
# ground-truth-labeler Time: 0.7564473152160645s
# 142.9483997821808
# 41480166_0_6681239260286218499.csv: 30 of 44
# clean Time: 0.007709026336669922s
# get-fuzzy-augmented-matches Time: 59.063284158706665s
# get-exact-matches Time: 11.317399501800537s
# ground-truth-labeler Time: 0.3702661991119385s
# 78.16272521018982
# 71840765_0_6664391841933033844.csv: 31 of 44
# clean Time: 0.0012979507446289062s
# get-fuzzy-augmented-matches Time: 11.365618705749512s
# get-exact-matches Time: 0.9291129112243652s
# ground-truth-labeler Time: 0.04357790946960449s
# 16.50344681739807
# 63450419_0_8012592961815711786.csv: 32 of 44
# clean Time: 0.007022857666015625s
# get-fuzzy-augmented-matches Time: 45.40343499183655s
# get-exact-matches Time: 7.7034876346588135s
# ground-truth-labeler Time: 0.33247995376586914s
# 59.115952014923096
# 35188621_0_6058553107571275232.csv: 33 of 44
# clean Time: 0.012894868850708008s
# get-fuzzy-augmented-matches Time: 31.413851737976074s
# get-exact-matches Time: 8.239839315414429s
# ground-truth-labeler Time: 0.21397614479064941s
# 45.77773404121399
# 25404227_0_2240631045609013057.csv: 34 of 44
# clean Time: 0.00426173210144043s
# get-fuzzy-augmented-matches Time: 22.073681116104126s
# get-exact-matches Time: 7.070289134979248s
# ground-truth-labeler Time: 0.2848701477050781s
# 35.12664556503296
# 90196673_0_5458330029110291950.csv: 35 of 44
# clean Time: 0.018003225326538086s
# get-fuzzy-augmented-matches Time: 77.07895374298096s
# get-exact-matches Time: 11.618256568908691s
# ground-truth-labeler Time: 0.6195883750915527s
# 96.99213147163391
# 39173938_0_7916056990138658530.csv: 36 of 44
# clean Time: 0.007390499114990234s
# get-fuzzy-augmented-matches Time: 22.474761247634888s
# get-exact-matches Time: 6.711711645126343s
# ground-truth-labeler Time: 0.20262646675109863s
# 34.99547553062439
# 10579449_0_1681126353774891032.csv: 37 of 44
# clean Time: 0.0022656917572021484s
# get-fuzzy-augmented-matches Time: 7.462184429168701s
# get-exact-matches Time: 1.1595327854156494s
# ground-truth-labeler Time: 0.0486598014831543s
# 12.971152067184448
# 1438042989018_40_20150728002309-00067-ip-10-236-191-2_57714692_2.csv: 38 of 44
# clean Time: 0.0018749237060546875s
# get-fuzzy-augmented-matches Time: 15.469257354736328s
# get-exact-matches Time: 2.6424267292022705s
# ground-truth-labeler Time: 0.058734893798828125s
# 22.38120675086975
# 8468806_0_4382447409703007384.csv: 39 of 44
# clean Time: 0.0039310455322265625s
# get-fuzzy-augmented-matches Time: 25.108513832092285s
# get-exact-matches Time: 7.769699573516846s
# ground-truth-labeler Time: 0.1490187644958496s
# 38.04182577133179
# 77694908_0_6083291340991074532.csv: 40 of 44
# clean Time: 0.0038030147552490234s
# get-fuzzy-augmented-matches Time: 17.094645500183105s
# get-exact-matches Time: 6.752174139022827s
# ground-truth-labeler Time: 0.20148754119873047s
# 29.753586292266846
# 50245608_0_871275842592178099.csv: 41 of 44
# clean Time: 0.012999773025512695s
# get-fuzzy-augmented-matches Time: 54.42345881462097s
# get-exact-matches Time: 16.3262460231781s
# ground-truth-labeler Time: 0.47857189178466797s
# 79.38174748420715
# 40534006_0_4617468856744635526.csv: 42 of 44
# clean Time: 0.00197601318359375s
# get-fuzzy-augmented-matches Time: 19.3632230758667s
# get-exact-matches Time: 2.372086524963379s
# ground-truth-labeler Time: 0.08562636375427246s
# 26.40338444709778
# 22864497_0_8632623712684511496.csv: 43 of 44
# clean Time: 0.011990547180175781s
# get-fuzzy-augmented-matches Time: 69.25405311584473s
# get-exact-matches Time: 13.687806129455566s
# ground-truth-labeler Time: 0.5617654323577881s
# 92.18482828140259
# 24036779_0_5608105867560183058.csv: 44 of 44
# clean Time: 0.0031549930572509766s
# get-fuzzy-augmented-matches Time: 18.012887954711914s
# get-exact-matches Time: 7.368627548217773s
# ground-truth-labeler Time: 0.7129018306732178s
# 32.460105180740356

# %%
candidate_generation(dev_path, ground_truth_files, dev_candidate_path, dev_class_count, dev_prop_count, dev_context_path, dev_graph_embedding)
# Out:
# 84575189_0_6365692015941409487.csv: 1 of 9
# clean Time: 0.012584447860717773s
# get-fuzzy-augmented-matches Time: 26.79003620147705s
# get-exact-matches Time: 6.977028846740723s
# ground-truth-labeler Time: 0.17999911308288574s
# 39.51597881317139
# 28086084_0_3127660530989916727.csv: 2 of 9
# clean Time: 0.007283210754394531s
# get-fuzzy-augmented-matches Time: 33.79224157333374s
# get-exact-matches Time: 7.863823175430298s
# ground-truth-labeler Time: 0.39851856231689453s
# 49.422181844711304
# 50270082_0_444360818941411589.csv: 3 of 9
# clean Time: 0.006052732467651367s
# get-fuzzy-augmented-matches Time: 45.74336504936218s
# get-exact-matches Time: 9.39232325553894s
# ground-truth-labeler Time: 0.48946475982666016s
# 62.08046865463257
# 29414811_2_4773219892816395776.csv: 4 of 9
# clean Time: 0.002878904342651367s
# get-fuzzy-augmented-matches Time: 9.171539068222046s
# get-exact-matches Time: 6.042067050933838s
# ground-truth-labeler Time: 0.05911731719970703s
# 20.13024115562439
# 39759273_0_1427898308030295194.csv: 5 of 9
# clean Time: 0.012944221496582031s
# get-fuzzy-augmented-matches Time: 17.76167058944702s
# get-exact-matches Time: 7.258527517318726s
# ground-truth-labeler Time: 0.2958838939666748s
# 31.22239589691162
# 14380604_4_3329235705746762392.csv: 6 of 9
# clean Time: 0.0025010108947753906s
# get-fuzzy-augmented-matches Time: 11.211555242538452s
# get-exact-matches Time: 3.016134738922119s
# ground-truth-labeler Time: 0.06533217430114746s
# 18.839250802993774
# 14067031_0_559833072073397908.csv: 7 of 9
# clean Time: 0.0074346065521240234s
# get-fuzzy-augmented-matches Time: 11.680546045303345s
# get-exact-matches Time: 6.10761833190918s
# ground-truth-labeler Time: 0.19803476333618164s
# 23.224818468093872
# 45073662_0_3179937335063201739.csv: 8 of 9
# clean Time: 0.00526738166809082s
# get-fuzzy-augmented-matches Time: 14.776865243911743s
# get-exact-matches Time: 5.756509304046631s
# ground-truth-labeler Time: 0.06207776069641113s
# 25.017224550247192
# 52299421_0_4473286348258170200.csv: 9 of 9
# clean Time: 0.011145591735839844s
# get-fuzzy-augmented-matches Time: 21.74451732635498s
# get-exact-matches Time: 7.404048681259155s
# ground-truth-labeler Time: 0.341097354888916s
# 36.21348190307617

# %% [markdown]
# ## Feature Generation

# %%
def feature_generation(candidate_dir, embedding_dir, class_count_dir, property_count_dir, context_path, output_path):
    file_list = glob.glob(candidate_dir + '/*.csv')
    for i, file in enumerate(file_list):
        filename = file.split('/')[-1]
        print(f"{filename}: {i+1} of {len(file_list)}")
        embedding_file = f"{embedding_dir}/{filename.strip('.csv')}_graph_embedding_complex.tsv"
        class_count_file = f"{class_count_dir}/{filename.strip('.csv')}_class_count.tsv"
        property_count_file = f"{property_count_dir}/{filename.strip('.csv')}_prop_count.tsv"
        context_file = f"{context_path}/{filename.strip('.csv')}_context.tsv"
        output_file = f"{output_path}/{filename}"
        classifier_features_str = ",".join(classifier_features)
        # !time tl align-page-rank $file \
            / string-similarity -i --method symmetric_monge_elkan:tokenizer=word -o monge_elkan \
            / string-similarity -i --method symmetric_monge_elkan:tokenizer=word -c label_clean kg_aliases -o monge_elkan_aliases \
            / string-similarity -i --method jaro_winkler -o jaro_winkler \
            / string-similarity -i --method levenshtein -o levenshtein \
            / string-similarity -i --method jaccard:tokenizer=word -c kg_descriptions context -o des_cont_jaccard \
            / normalize-scores -c des_cont_jaccard / smallest-qnode-number \
            / mosaic-features -c kg_labels --num-char --num-tokens \
            / create-singleton-feature -o singleton \
            / vote-by-classifier  \
            --prob-threshold 0.995 \
            --features $classifier_features_str \
            --model $classifier_model_path \
            / score-using-embedding \
            --column-vector-strategy centroid-of-lof \
            --lof-strategy ems-mv \
            -o lof-graph-embedding-score \
            --embedding-file $embedding_file \
            / generate-reciprocal-rank  \
            -c lof-graph-embedding-score \
            -o lof-reciprocal-rank \
            / compute-tf-idf  \
            --feature-file $class_count_file \
            --feature-name class_count \
            --singleton-column is_lof \
            -o lof_class_count_tf_idf_score \
            / compute-tf-idf \
            --feature-file $property_count_file \
            --feature-name property_count \
            --singleton-column is_lof \
            -o lof_property_count_tf_idf_score \
            / context-match --context-file $context_file \
            -o context_score \
            / create-pseudo-gt \
            --column-thresholds singleton:1,context_score:0.9\
            > $output_file

# %%
feature_generation(train_candidate_path, train_graph_embedding, train_class_count, train_prop_count, train_context_path, train_feature_path)
# Out:
# 37856682_0_6818907050314633217.csv: 1 of 44
# align-page-rank Time: 3.5839428901672363s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 17.59194803237915s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 20.15993309020996s
# string-similarity-['jaro_winkler'] Time: 3.8112339973449707s
# string-similarity-['levenshtein'] Time: 20.585536241531372s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.31127071380615234s
# normalize-scores-des_cont_jaccard Time: 0.18901801109313965s
# smallest-qnode-number Time: 3.2835514545440674s
# mosaic-features Time: 0.0931549072265625s
# creat-singleton-feature Time: 1.0386772155761719s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 2.6055452823638916s
# Qnodes to lookup: 43381
# Qnodes from file: 42173
# Outlier removal generates 286 lof-voted candidates
# score-using-embedding Time: 99.44141983985901s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 2.113983154296875s
# compute-tf-idf-class_count Time: 108.45605039596558s
# compute-tf-idf-property_count Time: 110.60635089874268s
# context-match Time: 40.399611473083496s
# create-pseudo-gt Time: 0.0037620067596435547s
#
# real	2m45.488s
# user	3m13.613s
# sys	0m6.717s
# 38428277_0_1311643810102462607.csv: 2 of 44
# align-page-rank Time: 2.1345365047454834s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 4.210623502731323s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 8.089579343795776s
# string-similarity-['jaro_winkler'] Time: 0.860156774520874s
# string-similarity-['levenshtein'] Time: 4.297551393508911s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.22679758071899414s
# normalize-scores-des_cont_jaccard Time: 0.05462002754211426s
# smallest-qnode-number Time: 0.7246782779693604s
# mosaic-features Time: 0.023348331451416016s
# creat-singleton-feature Time: 0.3143577575683594s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.34789180755615234s
# Qnodes to lookup: 12596
# Qnodes from file: 12189
# Outlier removal generates 119 lof-voted candidates
# score-using-embedding Time: 26.729950189590454s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.6939840316772461s
# compute-tf-idf-class_count Time: 29.087777137756348s
# compute-tf-idf-property_count Time: 29.77832293510437s
# context-match Time: 55.86010670661926s
# create-pseudo-gt Time: 0.004025697708129883s
#
# real	1m37.513s
# user	2m8.140s
# sys	0m3.304s
# 29414811_12_251152470253168163.csv: 3 of 44
# align-page-rank Time: 0.5951032638549805s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 1.4758944511413574s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 5.156288146972656s
# string-similarity-['jaro_winkler'] Time: 0.20026302337646484s
# string-similarity-['levenshtein'] Time: 1.4862666130065918s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.0437624454498291s
# normalize-scores-des_cont_jaccard Time: 0.015774250030517578s
# smallest-qnode-number Time: 0.11696028709411621s
# mosaic-features Time: 0.005650997161865234s
# creat-singleton-feature Time: 0.0662379264831543s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.33617615699768066s
# Qnodes to lookup: 1857
# Qnodes from file: 1790
# Outlier removal generates 13 lof-voted candidates
# score-using-embedding Time: 13.507055521011353s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.14003372192382812s
# compute-tf-idf-class_count Time: 14.310611724853516s
# compute-tf-idf-property_count Time: 14.334354162216187s
# context-match Time: 38.03836250305176s
# create-pseudo-gt Time: 0.0038101673126220703s
#
# real	1m3.263s
# user	1m32.787s
# sys	0m2.747s
# 9834884_0_3871985887467090123.csv: 4 of 44
# align-page-rank Time: 5.198324918746948s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 22.00988531112671s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 39.09425115585327s
# string-similarity-['jaro_winkler'] Time: 3.4748990535736084s
# string-similarity-['levenshtein'] Time: 27.190460681915283s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.45186376571655273s
# normalize-scores-des_cont_jaccard Time: 0.13223004341125488s
# smallest-qnode-number Time: 3.822441816329956s
# mosaic-features Time: 0.0626978874206543s
# creat-singleton-feature Time: 0.990511417388916s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.38658618927001953s
# Qnodes to lookup: 22923
# Qnodes from file: 22574
# Outlier removal generates 178 lof-voted candidates
# score-using-embedding Time: 115.0012001991272s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 2.016800880432129s
# compute-tf-idf-class_count Time: 120.5173487663269s
# compute-tf-idf-property_count Time: 122.17198276519775s
# context-match Time: 94.43581652641296s
# create-pseudo-gt Time: 0.004336118698120117s
#
# real	3m50.219s
# user	4m20.501s
# sys	0m5.207s
# 21245481_0_8730460088443117515.csv: 5 of 44
# align-page-rank Time: 3.4418656826019287s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 6.771147727966309s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 11.714591026306152s
# string-similarity-['jaro_winkler'] Time: 1.2105000019073486s
# string-similarity-['levenshtein'] Time: 8.612822771072388s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.2588348388671875s
# normalize-scores-des_cont_jaccard Time: 0.13205862045288086s
# smallest-qnode-number Time: 1.7873289585113525s
# mosaic-features Time: 0.035806894302368164s
# creat-singleton-feature Time: 0.5434525012969971s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.3926429748535156s
# Qnodes to lookup: 11850
# Qnodes from file: 11698
# Outlier removal generates 48 lof-voted candidates
# score-using-embedding Time: 42.388601303100586s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 1.2866971492767334s
# compute-tf-idf-class_count Time: 45.543261766433716s
# compute-tf-idf-property_count Time: 47.17435336112976s
# context-match Time: 57.47937846183777s
# create-pseudo-gt Time: 0.00422358512878418s
#
# real	1m57.411s
# user	2m26.860s
# sys	0m3.814s
# 39650055_5_7135804139753401681.csv: 6 of 44
# align-page-rank Time: 0.5939083099365234s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 1.9015541076660156s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 3.1611251831054688s
# string-similarity-['jaro_winkler'] Time: 0.663902759552002s
# string-similarity-['levenshtein'] Time: 2.0322134494781494s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.19280481338500977s
# normalize-scores-des_cont_jaccard Time: 0.07770919799804688s
# smallest-qnode-number Time: 0.6494355201721191s
# mosaic-features Time: 0.023809194564819336s
# creat-singleton-feature Time: 0.33093929290771484s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.35646748542785645s
# Qnodes to lookup: 13682
# Qnodes from file: 13069
# Outlier removal generates 40 lof-voted candidates
# score-using-embedding Time: 26.349472761154175s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.6712062358856201s
# compute-tf-idf-class_count Time: 30.599947929382324s
# compute-tf-idf-property_count Time: 31.911883115768433s
# context-match Time: 29.3450345993042s
# create-pseudo-gt Time: 0.003375530242919922s
#
# real	1m18.980s
# user	1m33.149s
# sys	0m3.493s
# 53989675_0_8697482470743954630.csv: 7 of 44
# align-page-rank Time: 0.5907995700836182s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.7221124172210693s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.9017333984375s
# string-similarity-['jaro_winkler'] Time: 0.14286375045776367s
# string-similarity-['levenshtein'] Time: 0.7043249607086182s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.05025482177734375s
# normalize-scores-des_cont_jaccard Time: 0.017475366592407227s
# smallest-qnode-number Time: 0.12561821937561035s
# mosaic-features Time: 0.006376504898071289s
# creat-singleton-feature Time: 0.0751957893371582s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.3427731990814209s
# Qnodes to lookup: 2161
# Qnodes from file: 2144
# Outlier removal generates 3 lof-voted candidates
# score-using-embedding Time: 7.473616123199463s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.15734243392944336s
# compute-tf-idf-class_count Time: 8.324704647064209s
# compute-tf-idf-property_count Time: 8.608874082565308s
# context-match Time: 9.825561285018921s
# create-pseudo-gt Time: 0.0039031505584716797s
#
# real	0m29.172s
# user	0m59.018s
# sys	0m2.617s
# 99070098_0_2074872741302696997.csv: 8 of 44
# align-page-rank Time: 2.9259960651397705s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 3.3463590145111084s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 6.5744123458862305s
# string-similarity-['jaro_winkler'] Time: 0.8636167049407959s
# string-similarity-['levenshtein'] Time: 3.4296603202819824s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.5346236228942871s
# normalize-scores-des_cont_jaccard Time: 0.07684183120727539s
# smallest-qnode-number Time: 1.606400489807129s
# mosaic-features Time: 0.032714128494262695s
# creat-singleton-feature Time: 0.5747706890106201s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.6591231822967529s
# Qnodes to lookup: 12078
# Qnodes from file: 11859
# _centroid_of_lof: Missing 1 of 172
# Outlier removal generates 103 lof-voted candidates
# score-using-embedding Time: 28.032695770263672s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 1.1831254959106445s
# compute-tf-idf-class_count Time: 31.172537088394165s
# compute-tf-idf-property_count Time: 32.63362669944763s
# context-match Time: 115.6623888015747s
# create-pseudo-gt Time: 0.003970623016357422s
#
# real	2m40.136s
# user	3m10.485s
# sys	0m3.729s
# 46671561_0_6122315295162029872.csv: 9 of 44
# align-page-rank Time: 2.9269537925720215s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 8.337658643722534s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 14.114617109298706s
# string-similarity-['jaro_winkler'] Time: 1.2822065353393555s
# string-similarity-['levenshtein'] Time: 8.206635236740112s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.2395467758178711s
# normalize-scores-des_cont_jaccard Time: 0.07105398178100586s
# smallest-qnode-number Time: 1.3197729587554932s
# mosaic-features Time: 0.03095531463623047s
# creat-singleton-feature Time: 0.4816269874572754s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.36374354362487793s
# Qnodes to lookup: 15698
# Qnodes from file: 15130
# Outlier removal generates 121 lof-voted candidates
# score-using-embedding Time: 44.60119962692261s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 1.0168907642364502s
# compute-tf-idf-class_count Time: 47.5669207572937s
# compute-tf-idf-property_count Time: 48.45442771911621s
# context-match Time: 113.09411931037903s
# create-pseudo-gt Time: 0.004253864288330078s
#
# real	2m54.478s
# user	3m25.690s
# sys	0m3.747s
# 80588006_0_6965325215443683359.csv: 10 of 44
# align-page-rank Time: 0.31468796730041504s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.37907886505126953s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.8633716106414795s
# string-similarity-['jaro_winkler'] Time: 0.09495925903320312s
# string-similarity-['levenshtein'] Time: 0.40535736083984375s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.02378535270690918s
# normalize-scores-des_cont_jaccard Time: 0.01509404182434082s
# smallest-qnode-number Time: 0.10194754600524902s
# mosaic-features Time: 0.004875659942626953s
# creat-singleton-feature Time: 0.05618095397949219s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 1.4575731754302979s
# Qnodes to lookup: 1855
# Qnodes from file: 1809
# Outlier removal generates 8 lof-voted candidates
# score-using-embedding Time: 7.648217678070068s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.12589812278747559s
# compute-tf-idf-class_count Time: 8.411717891693115s
# compute-tf-idf-property_count Time: 8.977876663208008s
# context-match Time: 0.2566564083099365s
# create-pseudo-gt Time: 0.004149913787841797s
#
# real	0m19.743s
# user	0m48.381s
# sys	0m2.654s
# 20135078_0_7570343137119682530.csv: 11 of 44
# align-page-rank Time: 1.661864995956421s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 3.784299612045288s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 6.653662443161011s
# string-similarity-['jaro_winkler'] Time: 0.7297070026397705s
# string-similarity-['levenshtein'] Time: 3.717109441757202s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.2004871368408203s
# normalize-scores-des_cont_jaccard Time: 0.04738783836364746s
# smallest-qnode-number Time: 0.6076066493988037s
# mosaic-features Time: 0.02106332778930664s
# creat-singleton-feature Time: 0.28036928176879883s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.35110974311828613s
# Qnodes to lookup: 11210
# Qnodes from file: 10918
# Outlier removal generates 104 lof-voted candidates
# score-using-embedding Time: 23.83616542816162s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.6224400997161865s
# compute-tf-idf-class_count Time: 26.135606288909912s
# compute-tf-idf-property_count Time: 26.637563228607178s
# context-match Time: 55.93819761276245s
# create-pseudo-gt Time: 0.003936767578125s
#
# real	1m34.253s
# user	2m4.882s
# sys	0m3.105s
# 39107734_2_2329160387535788734.csv: 12 of 44
# align-page-rank Time: 0.5880599021911621s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 4.736791372299194s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 5.974607467651367s
# string-similarity-['jaro_winkler'] Time: 0.7687458992004395s
# string-similarity-['levenshtein'] Time: 6.88549542427063s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.10924220085144043s
# normalize-scores-des_cont_jaccard Time: 0.023601770401000977s
# smallest-qnode-number Time: 0.2503468990325928s
# mosaic-features Time: 0.010849952697753906s
# creat-singleton-feature Time: 0.12829923629760742s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.35686802864074707s
# Qnodes to lookup: 3480
# Qnodes from file: 3403
# Outlier removal generates 53 lof-voted candidates
# score-using-embedding Time: 24.771339178085327s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.29511594772338867s
# compute-tf-idf-class_count Time: 25.94375228881836s
# compute-tf-idf-property_count Time: 26.50812554359436s
# context-match Time: 60.51843237876892s
# create-pseudo-gt Time: 0.003864765167236328s
#
# real	1m37.830s
# user	2m8.009s
# sys	0m2.820s
# 58891288_0_1117541047012405958.csv: 13 of 44
# align-page-rank Time: 1.4625704288482666s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 4.038693428039551s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 9.524704456329346s
# string-similarity-['jaro_winkler'] Time: 0.7399322986602783s
# string-similarity-['levenshtein'] Time: 4.160364389419556s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.19028973579406738s
# normalize-scores-des_cont_jaccard Time: 0.047763824462890625s
# smallest-qnode-number Time: 0.6272149085998535s
# mosaic-features Time: 0.02013993263244629s
# creat-singleton-feature Time: 0.28182482719421387s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.35545921325683594s
# Qnodes to lookup: 10717
# Qnodes from file: 10399
# Outlier removal generates 89 lof-voted candidates
# score-using-embedding Time: 27.642427444458008s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.5855319499969482s
# compute-tf-idf-class_count Time: 29.706815719604492s
# compute-tf-idf-property_count Time: 30.417898416519165s
# context-match Time: 48.92568922042847s
# create-pseudo-gt Time: 0.0032401084899902344s
#
# real	1m30.688s
# user	2m1.160s
# sys	0m3.161s
# 84548468_0_5955155464119382182.csv: 14 of 44
# align-page-rank Time: 1.576369285583496s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 3.430727005004883s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 5.870925426483154s
# string-similarity-['jaro_winkler'] Time: 0.6832740306854248s
# string-similarity-['levenshtein'] Time: 3.7551066875457764s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.18540120124816895s
# normalize-scores-des_cont_jaccard Time: 0.04509687423706055s
# smallest-qnode-number Time: 0.5837259292602539s
# mosaic-features Time: 0.020215511322021484s
# creat-singleton-feature Time: 0.27297306060791016s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.4010617733001709s
# Qnodes to lookup: 10574
# Qnodes from file: 10229
# Outlier removal generates 83 lof-voted candidates
# score-using-embedding Time: 22.57669472694397s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.6122696399688721s
# compute-tf-idf-class_count Time: 24.563704252243042s
# compute-tf-idf-property_count Time: 25.07721257209778s
# context-match Time: 47.919981718063354s
# create-pseudo-gt Time: 0.003863811492919922s
#
# real	1m24.750s
# user	1m54.832s
# sys	0m3.137s
# 16767252_0_2409448375013995751.csv: 15 of 44
# align-page-rank Time: 1.365325927734375s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 3.1862549781799316s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 4.802372217178345s
# string-similarity-['jaro_winkler'] Time: 0.6070311069488525s
# string-similarity-['levenshtein'] Time: 3.1664514541625977s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.15636968612670898s
# normalize-scores-des_cont_jaccard Time: 0.040447235107421875s
# smallest-qnode-number Time: 0.5118188858032227s
# mosaic-features Time: 0.017330646514892578s
# creat-singleton-feature Time: 0.23638916015625s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.34678101539611816s
# Qnodes to lookup: 8871
# Qnodes from file: 8627
# Outlier removal generates 93 lof-voted candidates
# score-using-embedding Time: 20.058007955551147s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.5152809619903564s
# compute-tf-idf-class_count Time: 21.356199026107788s
# compute-tf-idf-property_count Time: 21.879175186157227s
# context-match Time: 44.621689796447754s
# create-pseudo-gt Time: 0.0039000511169433594s
#
# real	1m18.172s
# user	1m48.808s
# sys	0m3.014s
# 88523363_0_8180214313099580515.csv: 16 of 44
# align-page-rank Time: 9.270045280456543s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 12.463760614395142s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 14.247629880905151s
# string-similarity-['jaro_winkler'] Time: 3.402780055999756s
# string-similarity-['levenshtein'] Time: 19.018203258514404s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.7354423999786377s
# normalize-scores-des_cont_jaccard Time: 0.1897268295288086s
# smallest-qnode-number Time: 7.152432203292847s
# mosaic-features Time: 0.08506989479064941s
# creat-singleton-feature Time: 1.8370511531829834s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.4231114387512207s
# Qnodes to lookup: 42234
# Qnodes from file: 41968
# Outlier removal generates 351 lof-voted candidates
# score-using-embedding Time: 86.16092920303345s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 3.2451891899108887s
# compute-tf-idf-class_count Time: 92.58734846115112s
# compute-tf-idf-property_count Time: 95.02254295349121s
# context-match Time: 210.35485577583313s
# create-pseudo-gt Time: 0.003719329833984375s
#
# real	5m20.205s
# user	5m48.856s
# sys	0m7.266s
# 69537082_0_7789694313271016902.csv: 17 of 44
# align-page-rank Time: 3.8692729473114014s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 16.71731424331665s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 18.703869581222534s
# string-similarity-['jaro_winkler'] Time: 3.907064437866211s
# string-similarity-['levenshtein'] Time: 20.271073579788208s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.502312421798706s
# normalize-scores-des_cont_jaccard Time: 0.14068055152893066s
# smallest-qnode-number Time: 2.5389068126678467s
# mosaic-features Time: 0.07875800132751465s
# creat-singleton-feature Time: 0.8598952293395996s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.37818193435668945s
# Qnodes to lookup: 36385
# Qnodes from file: 35280
# Outlier removal generates 235 lof-voted candidates
# score-using-embedding Time: 82.63561630249023s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 1.7370021343231201s
# compute-tf-idf-class_count Time: 88.11707353591919s
# compute-tf-idf-property_count Time: 89.84301090240479s
# context-match Time: 10.374650239944458s
# create-pseudo-gt Time: 0.004422664642333984s
#
# real	1m54.588s
# user	2m24.747s
# sys	0m4.878s
# 33401079_0_9127583903019856402.csv: 18 of 44
# align-page-rank Time: 1.438978910446167s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 2.630197763442993s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 7.649493455886841s
# string-similarity-['jaro_winkler'] Time: 0.5699269771575928s
# string-similarity-['levenshtein'] Time: 3.3385543823242188s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.09335136413574219s
# normalize-scores-des_cont_jaccard Time: 0.03708171844482422s
# smallest-qnode-number Time: 0.474776029586792s
# mosaic-features Time: 0.015251636505126953s
# creat-singleton-feature Time: 0.20422983169555664s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.34007978439331055s
# Qnodes to lookup: 8276
# Qnodes from file: 8183
# Outlier removal generates 62 lof-voted candidates
# score-using-embedding Time: 21.92274236679077s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.45206642150878906s
# compute-tf-idf-class_count Time: 23.901442766189575s
# compute-tf-idf-property_count Time: 24.10582995414734s
# context-match Time: 135.02922987937927s
# create-pseudo-gt Time: 0.0037970542907714844s
#
# real	2m50.924s
# user	3m21.136s
# sys	0m3.211s
# 1438042989043_35_20150728002309-00287-ip-10-236-191-2_875026214_2.csv: 19 of 44
# align-page-rank Time: 0.4630765914916992s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.3692023754119873s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.6124460697174072s
# string-similarity-['jaro_winkler'] Time: 0.10695028305053711s
# string-similarity-['levenshtein'] Time: 0.4248619079589844s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.028928756713867188s
# normalize-scores-des_cont_jaccard Time: 0.014348506927490234s
# smallest-qnode-number Time: 0.0901174545288086s
# mosaic-features Time: 0.004946470260620117s
# creat-singleton-feature Time: 0.058884620666503906s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.3337440490722656s
# Qnodes to lookup: 1234
# Qnodes from file: 1218
# Outlier removal generates 5 lof-voted candidates
# score-using-embedding Time: 6.204716682434082s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.11887383460998535s
# compute-tf-idf-class_count Time: 7.456602573394775s
# compute-tf-idf-property_count Time: 7.071047782897949s
# context-match Time: 17.864810466766357s
# create-pseudo-gt Time: 0.003916263580322266s
#
# real	0m35.706s
# user	1m5.204s
# sys	0m2.523s
# 26310680_0_5150772059999313798.csv: 20 of 44
# align-page-rank Time: 4.0776965618133545s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 16.250107526779175s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 19.502161741256714s
# string-similarity-['jaro_winkler'] Time: 3.4997718334198s
# string-similarity-['levenshtein'] Time: 20.40747618675232s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.46642279624938965s
# normalize-scores-des_cont_jaccard Time: 0.13854122161865234s
# smallest-qnode-number Time: 2.883145332336426s
# mosaic-features Time: 0.07742500305175781s
# creat-singleton-feature Time: 0.8466339111328125s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.38950371742248535s
# Qnodes to lookup: 35193
# Qnodes from file: 34092
# Outlier removal generates 216 lof-voted candidates
# score-using-embedding Time: 83.49281167984009s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 1.78912353515625s
# compute-tf-idf-class_count Time: 88.93705558776855s
# compute-tf-idf-property_count Time: 90.64838290214539s
# context-match Time: 211.7805037498474s
# create-pseudo-gt Time: 0.004270792007446289s
#
# real	5m16.653s
# user	5m45.910s
# sys	0m4.960s
# 60319454_0_3938426910282115527.csv: 21 of 44
# align-page-rank Time: 0.9458255767822266s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 1.1264772415161133s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 1.7328906059265137s
# string-similarity-['jaro_winkler'] Time: 0.2952384948730469s
# string-similarity-['levenshtein'] Time: 1.434483528137207s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.05521416664123535s
# normalize-scores-des_cont_jaccard Time: 0.025150060653686523s
# smallest-qnode-number Time: 0.23619389533996582s
# mosaic-features Time: 0.010394573211669922s
# creat-singleton-feature Time: 0.13038158416748047s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.33577466011047363s
# Qnodes to lookup: 5005
# Qnodes from file: 4886
# Outlier removal generates 24 lof-voted candidates
# score-using-embedding Time: 10.491532802581787s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.27877116203308105s
# compute-tf-idf-class_count Time: 11.579498291015625s
# compute-tf-idf-property_count Time: 11.806498765945435s
# context-match Time: 27.38714599609375s
# create-pseudo-gt Time: 0.003973484039306641s
#
# real	0m50.354s
# user	1m20.499s
# sys	0m2.793s
# 91959037_0_7907661684242014480.csv: 22 of 44
# align-page-rank Time: 5.409379720687866s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 18.47635555267334s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 37.18193864822388s
# string-similarity-['jaro_winkler'] Time: 2.825488805770874s
# string-similarity-['levenshtein'] Time: 18.84561014175415s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.6354465484619141s
# normalize-scores-des_cont_jaccard Time: 0.13965129852294922s
# smallest-qnode-number Time: 4.120271682739258s
# mosaic-features Time: 0.06715059280395508s
# creat-singleton-feature Time: 1.1035830974578857s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.3870089054107666s
# Qnodes to lookup: 22297
# Qnodes from file: 21621
# Outlier removal generates 102 lof-voted candidates
# score-using-embedding Time: 101.84574151039124s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 2.162048578262329s
# compute-tf-idf-class_count Time: 107.19165921211243s
# compute-tf-idf-property_count Time: 108.96857810020447s
# context-match Time: 86.36211442947388s
# create-pseudo-gt Time: 0.004273891448974609s
#
# real	3m29.275s
# user	3m59.730s
# sys	0m4.894s
# 9567241_0_5666388268510912770.csv: 23 of 44
# align-page-rank Time: 0.5057024955749512s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.47277259826660156s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.8949573040008545s
# string-similarity-['jaro_winkler'] Time: 0.10285449028015137s
# string-similarity-['levenshtein'] Time: 0.4360771179199219s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.024401426315307617s
# normalize-scores-des_cont_jaccard Time: 0.014696598052978516s
# smallest-qnode-number Time: 0.11455154418945312s
# mosaic-features Time: 0.0053730010986328125s
# creat-singleton-feature Time: 0.05414867401123047s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.3317844867706299s
# Qnodes to lookup: 1922
# Qnodes from file: 1861
# Outlier removal generates 7 lof-voted candidates
# score-using-embedding Time: 6.740741729736328s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.12123370170593262s
# compute-tf-idf-class_count Time: 7.863901376724243s
# compute-tf-idf-property_count Time: 7.485363006591797s
# context-match Time: 0.2155745029449463s
# create-pseudo-gt Time: 0.003883838653564453s
#
# real	0m18.603s
# user	0m48.136s
# sys	0m2.543s
# 21362676_0_6854186738074119688.csv: 24 of 44
# align-page-rank Time: 1.5169978141784668s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 4.22599196434021s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 10.347371816635132s
# string-similarity-['jaro_winkler'] Time: 0.7555856704711914s
# string-similarity-['levenshtein'] Time: 4.323064088821411s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.19310975074768066s
# normalize-scores-des_cont_jaccard Time: 0.04659080505371094s
# smallest-qnode-number Time: 0.5939733982086182s
# mosaic-features Time: 0.02007770538330078s
# creat-singleton-feature Time: 0.301652193069458s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.3443601131439209s
# Qnodes to lookup: 10157
# Qnodes from file: 9877
# Outlier removal generates 109 lof-voted candidates
# score-using-embedding Time: 28.533332347869873s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.5699524879455566s
# compute-tf-idf-class_count Time: 30.551419019699097s
# compute-tf-idf-property_count Time: 31.047550678253174s
# context-match Time: 52.96243119239807s
# create-pseudo-gt Time: 0.003835439682006836s
#
# real	1m35.833s
# user	2m5.970s
# sys	0m3.436s
# 54719588_0_8417197176086756912.csv: 25 of 44
# align-page-rank Time: 3.3705224990844727s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 7.883110523223877s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 13.602859497070312s
# string-similarity-['jaro_winkler'] Time: 1.6004045009613037s
# string-similarity-['levenshtein'] Time: 8.282814025878906s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.7449240684509277s
# normalize-scores-des_cont_jaccard Time: 0.09859323501586914s
# smallest-qnode-number Time: 1.9769878387451172s
# mosaic-features Time: 0.045511722564697266s
# creat-singleton-feature Time: 0.6764616966247559s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.3795289993286133s
# Qnodes to lookup: 24211
# Qnodes from file: 23278
# Outlier removal generates 77 lof-voted candidates
# score-using-embedding Time: 48.099098205566406s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 1.399327278137207s
# compute-tf-idf-class_count Time: 52.895177602767944s
# compute-tf-idf-property_count Time: 53.662434339523315s
# context-match Time: 227.2061004638672s
# create-pseudo-gt Time: 0.004150390625s
#
# real	4m54.015s
# user	5m23.928s
# sys	0m4.240s
# 1438042986423_95_20150728002306-00125-ip-10-236-191-2_88435628_5.csv: 26 of 44
# align-page-rank Time: 0.18613791465759277s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.23938512802124023s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.33393406867980957s
# string-similarity-['jaro_winkler'] Time: 0.07945489883422852s
# string-similarity-['levenshtein'] Time: 0.2779269218444824s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.025703907012939453s
# normalize-scores-des_cont_jaccard Time: 0.013579607009887695s
# smallest-qnode-number Time: 0.04383993148803711s
# mosaic-features Time: 0.00406956672668457s
# creat-singleton-feature Time: 0.039642333984375s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.3324246406555176s
# Qnodes to lookup: 1237
# Qnodes from file: 1179
# Outlier removal generates 4 lof-voted candidates
# score-using-embedding Time: 5.8149213790893555s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.07239532470703125s
# compute-tf-idf-class_count Time: 6.53390097618103s
# compute-tf-idf-property_count Time: 6.892439126968384s
# context-match Time: 0.20103240013122559s
# create-pseudo-gt Time: 0.003864765167236328s
#
# real	0m17.781s
# user	0m46.362s
# sys	0m2.540s
# 43237185_1_3636357855502246981.csv: 27 of 44
# align-page-rank Time: 0.33635807037353516s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.7583491802215576s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 1.885572910308838s
# string-similarity-['jaro_winkler'] Time: 0.16942644119262695s
# string-similarity-['levenshtein'] Time: 0.925612211227417s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.04868721961975098s
# normalize-scores-des_cont_jaccard Time: 0.016570329666137695s
# smallest-qnode-number Time: 0.12400174140930176s
# mosaic-features Time: 0.006015777587890625s
# creat-singleton-feature Time: 0.06781172752380371s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.3357229232788086s
# Qnodes to lookup: 2611
# Qnodes from file: 2573
# Outlier removal generates 16 lof-voted candidates
# score-using-embedding Time: 8.932729959487915s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.15549993515014648s
# compute-tf-idf-class_count Time: 10.293527364730835s
# compute-tf-idf-property_count Time: 10.436296224594116s
# context-match Time: 65.5068416595459s
# create-pseudo-gt Time: 0.0037505626678466797s
#
# real	1m26.803s
# user	1m56.395s
# sys	0m2.808s
# 29414811_13_8724394428539174350.csv: 28 of 44
# align-page-rank Time: 0.17392563819885254s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 1.1821203231811523s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 3.0673274993896484s
# string-similarity-['jaro_winkler'] Time: 0.13652420043945312s
# string-similarity-['levenshtein'] Time: 0.995495080947876s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.03161215782165527s
# normalize-scores-des_cont_jaccard Time: 0.012871503829956055s
# smallest-qnode-number Time: 0.07957077026367188s
# mosaic-features Time: 0.0043828487396240234s
# creat-singleton-feature Time: 0.04243135452270508s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.33474302291870117s
# Qnodes to lookup: 1140
# Qnodes from file: 1102
# Outlier removal generates 6 lof-voted candidates
# score-using-embedding Time: 10.45792818069458s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.0960242748260498s
# compute-tf-idf-class_count Time: 11.071792602539062s
# compute-tf-idf-property_count Time: 11.239681720733643s
# context-match Time: 21.984282970428467s
# create-pseudo-gt Time: 0.004349946975708008s
#
# real	0m43.491s
# user	1m13.296s
# sys	0m2.655s
# 53822652_0_5767892317858575530.csv: 29 of 44
# align-page-rank Time: 7.050548553466797s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 13.883949995040894s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 22.988377332687378s
# string-similarity-['jaro_winkler'] Time: 2.8706984519958496s
# string-similarity-['levenshtein'] Time: 14.464658260345459s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.6180222034454346s
# normalize-scores-des_cont_jaccard Time: 0.17086052894592285s
# smallest-qnode-number Time: 5.08288049697876s
# mosaic-features Time: 0.07559323310852051s
# creat-singleton-feature Time: 1.2987840175628662s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.40496397018432617s
# Qnodes to lookup: 43141
# Qnodes from file: 41724
# _centroid_of_lof: Missing 1 of 233
# Outlier removal generates 139 lof-voted candidates
# score-using-embedding Time: 84.75041246414185s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 2.496579885482788s
# compute-tf-idf-class_count Time: 91.7292697429657s
# compute-tf-idf-property_count Time: 94.27704572677612s
# context-match Time: 267.2769134044647s
# create-pseudo-gt Time: 0.0044460296630859375s
#
# real	6m16.464s
# user	6m45.394s
# sys	0m6.151s
# 41480166_0_6681239260286218499.csv: 30 of 44
# align-page-rank Time: 3.226585865020752s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 9.361800193786621s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 24.38023352622986s
# string-similarity-['jaro_winkler'] Time: 1.962156057357788s
# string-similarity-['levenshtein'] Time: 9.868385791778564s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.48293185234069824s
# normalize-scores-des_cont_jaccard Time: 0.08992862701416016s
# smallest-qnode-number Time: 1.7632639408111572s
# mosaic-features Time: 0.04348158836364746s
# creat-singleton-feature Time: 0.6762261390686035s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.37238264083862305s
# Qnodes to lookup: 19531
# Qnodes from file: 19257
# Outlier removal generates 89 lof-voted candidates
# score-using-embedding Time: 61.64423656463623s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 1.3087880611419678s
# compute-tf-idf-class_count Time: 65.3067946434021s
# compute-tf-idf-property_count Time: 66.77937912940979s
# context-match Time: 220.528883934021s
# create-pseudo-gt Time: 0.005187511444091797s
#
# real	5m0.462s
# user	5m30.984s
# sys	0m4.112s
# 71840765_0_6664391841933033844.csv: 31 of 44
# align-page-rank Time: 0.1995236873626709s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.34224486351013184s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.529273271560669s
# string-similarity-['jaro_winkler'] Time: 0.07866191864013672s
# string-similarity-['levenshtein'] Time: 0.30643463134765625s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.017992019653320312s
# normalize-scores-des_cont_jaccard Time: 0.012284994125366211s
# smallest-qnode-number Time: 0.06781888008117676s
# mosaic-features Time: 0.003962278366088867s
# creat-singleton-feature Time: 0.04065132141113281s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.3300032615661621s
# Qnodes to lookup: 1100
# Qnodes from file: 1094
# Outlier removal generates 11 lof-voted candidates
# score-using-embedding Time: 5.742921590805054s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.08982658386230469s
# compute-tf-idf-class_count Time: 6.7289063930511475s
# compute-tf-idf-property_count Time: 6.911860227584839s
# context-match Time: 0.38111281394958496s
# create-pseudo-gt Time: 0.0032541751861572266s
#
# real	0m17.833s
# user	0m47.363s
# sys	0m2.639s
# 63450419_0_8012592961815711786.csv: 32 of 44
# align-page-rank Time: 3.289363384246826s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 5.003397226333618s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 5.1449830532073975s
# string-similarity-['jaro_winkler'] Time: 1.2319433689117432s
# string-similarity-['levenshtein'] Time: 7.554899215698242s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.20869064331054688s
# normalize-scores-des_cont_jaccard Time: 0.08088040351867676s
# smallest-qnode-number Time: 1.5949833393096924s
# mosaic-features Time: 0.02927565574645996s
# creat-singleton-feature Time: 0.48657989501953125s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.35680055618286133s
# Qnodes to lookup: 13769
# Qnodes from file: 13691
# Outlier removal generates 116 lof-voted candidates
# score-using-embedding Time: 32.08714413642883s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 1.0641427040100098s
# compute-tf-idf-class_count Time: 34.65411067008972s
# compute-tf-idf-property_count Time: 35.390695571899414s
# context-match Time: 38.30941581726074s
# create-pseudo-gt Time: 0.00405430793762207s
#
# real	1m26.657s
# user	1m56.975s
# sys	0m3.678s
# 35188621_0_6058553107571275232.csv: 33 of 44
# align-page-rank Time: 1.8497462272644043s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 3.8270461559295654s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 6.3411664962768555s
# string-similarity-['jaro_winkler'] Time: 0.7968637943267822s
# string-similarity-['levenshtein'] Time: 4.129273414611816s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.21291303634643555s
# normalize-scores-des_cont_jaccard Time: 0.05225014686584473s
# smallest-qnode-number Time: 0.7069711685180664s
# mosaic-features Time: 0.022095441818237305s
# creat-singleton-feature Time: 0.31577587127685547s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.35099124908447266s
# Qnodes to lookup: 11833
# Qnodes from file: 11460
# _centroid_of_lof: Missing 1 of 177
# Outlier removal generates 106 lof-voted candidates
# score-using-embedding Time: 24.68522000312805s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.6744933128356934s
# compute-tf-idf-class_count Time: 26.89585018157959s
# compute-tf-idf-property_count Time: 27.427452087402344s
# context-match Time: 60.41639304161072s
# create-pseudo-gt Time: 0.00561833381652832s
#
# real	1m41.207s
# user	2m10.919s
# sys	0m4.486s
# 25404227_0_2240631045609013057.csv: 34 of 44
# align-page-rank Time: 2.1172900199890137s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 5.792541027069092s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 12.565030574798584s
# string-similarity-['jaro_winkler'] Time: 0.975243091583252s
# string-similarity-['levenshtein'] Time: 6.209139108657837s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.1935882568359375s
# normalize-scores-des_cont_jaccard Time: 0.04610610008239746s
# smallest-qnode-number Time: 0.8400957584381104s
# mosaic-features Time: 0.021547317504882812s
# creat-singleton-feature Time: 0.2777247428894043s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.36116790771484375s
# Qnodes to lookup: 10026
# Qnodes from file: 9732
# _centroid_of_lof: Missing 1 of 172
# Outlier removal generates 104 lof-voted candidates
# score-using-embedding Time: 35.32508873939514s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.7111902236938477s
# compute-tf-idf-class_count Time: 37.91723012924194s
# compute-tf-idf-property_count Time: 38.123995304107666s
# context-match Time: 60.201910734176636s
# create-pseudo-gt Time: 0.004081249237060547s
# real	1m51.356s
# user	2m22.280s
# sys	0m3.406s
# 90196673_0_5458330029110291950.csv: 35 of 44
# align-page-rank Time: 7.00242280960083s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 16.852534294128418s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 18.755080461502075s
# string-similarity-['jaro_winkler'] Time: 3.489022970199585s
# string-similarity-['levenshtein'] Time: 16.916688442230225s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.4146902561187744s
# normalize-scores-des_cont_jaccard Time: 0.1455090045928955s
# smallest-qnode-number Time: 4.542864561080933s
# mosaic-features Time: 0.06823492050170898s
# creat-singleton-feature Time: 1.3138232231140137s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.4051661491394043s
# Qnodes to lookup: 22360
# Qnodes from file: 21926
# Outlier removal generates 144 lof-voted candidates
# score-using-embedding Time: 84.75564098358154s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 2.7934882640838623s
# compute-tf-idf-class_count Time: 90.92087960243225s
# compute-tf-idf-property_count Time: 92.9131965637207s
# context-match Time: 207.31573224067688s
# create-pseudo-gt Time: 0.004480838775634766s
#
# real	5m16.029s
# user	5m44.948s
# sys	0m6.032s
# 39173938_0_7916056990138658530.csv: 36 of 44
# align-page-rank Time: 0.5977511405944824s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 3.4338009357452393s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 6.544444561004639s
# string-similarity-['jaro_winkler'] Time: 0.6561880111694336s
# string-similarity-['levenshtein'] Time: 3.7782633304595947s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.17088913917541504s
# normalize-scores-des_cont_jaccard Time: 0.043128013610839844s
# smallest-qnode-number Time: 0.5828227996826172s
# mosaic-features Time: 0.024739503860473633s
# creat-singleton-feature Time: 0.26596927642822266s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 1.3346045017242432s
# Qnodes to lookup: 9987
# Qnodes from file: 9719
# Outlier removal generates 83 lof-voted candidates
# score-using-embedding Time: 35.36616539955139s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.578296422958374s
# compute-tf-idf-class_count Time: 38.04482078552246s
# compute-tf-idf-property_count Time: 38.89892053604126s
# context-match Time: 48.80326700210571s
# create-pseudo-gt Time: 0.004024982452392578s
#
# real	1m40.929s
# user	2m9.173s
# sys	0m4.194s
# 10579449_0_1681126353774891032.csv: 37 of 44
# align-page-rank Time: 0.5206887722015381s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.34699392318725586s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.6219797134399414s
# string-similarity-['jaro_winkler'] Time: 0.08770060539245605s
# string-similarity-['levenshtein'] Time: 0.3724935054779053s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.024774551391601562s
# normalize-scores-des_cont_jaccard Time: 0.01334071159362793s
# smallest-qnode-number Time: 0.10193943977355957s
# mosaic-features Time: 0.0045468807220458984s
# creat-singleton-feature Time: 0.05217409133911133s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.3353865146636963s
# Qnodes to lookup: 1706
# Qnodes from file: 1652
# _centroid_of_lof: Missing 1 of 14
# Outlier removal generates 9 lof-voted candidates
# score-using-embedding Time: 6.464565277099609s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.11724233627319336s
# compute-tf-idf-class_count Time: 7.200769662857056s
# compute-tf-idf-property_count Time: 7.285489320755005s
# context-match Time: 0.21938276290893555s
# create-pseudo-gt Time: 0.004971027374267578s
#
# real	0m19.410s
# user	0m48.570s
# sys	0m2.639s
# 1438042989018_40_20150728002309-00067-ip-10-236-191-2_57714692_2.csv: 38 of 44
# align-page-rank Time: 0.18287920951843262s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.24356532096862793s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.4433610439300537s
# string-similarity-['jaro_winkler'] Time: 0.05603909492492676s
# string-similarity-['levenshtein'] Time: 0.20060467720031738s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.03636288642883301s
# normalize-scores-des_cont_jaccard Time: 0.012475967407226562s
# smallest-qnode-number Time: 0.03389167785644531s
# mosaic-features Time: 0.003664255142211914s
# creat-singleton-feature Time: 0.03436779975891113s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.34050559997558594s
# Qnodes to lookup: 980
# Qnodes from file: 976
# Outlier removal generates 2 lof-voted candidates
# score-using-embedding Time: 6.434914827346802s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.08130884170532227s
# compute-tf-idf-class_count Time: 7.117994546890259s
# compute-tf-idf-property_count Time: 7.094403266906738s
# context-match Time: 3.1465225219726562s
# create-pseudo-gt Time: 0.0033731460571289062s
#
# real	0m22.025s
# user	0m52.010s
# sys	0m2.708s
# 8468806_0_4382447409703007384.csv: 39 of 44
# align-page-rank Time: 2.1821250915527344s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 1.292757511138916s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 2.062134265899658s
# string-similarity-['jaro_winkler'] Time: 0.4066295623779297s
# string-similarity-['levenshtein'] Time: 1.7988977432250977s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.21459031105041504s
# normalize-scores-des_cont_jaccard Time: 0.03734016418457031s
# smallest-qnode-number Time: 0.5980844497680664s
# mosaic-features Time: 0.015934467315673828s
# creat-singleton-feature Time: 0.22574353218078613s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.3475971221923828s
# Qnodes to lookup: 6739
# Qnodes from file: 6672
# Outlier removal generates 42 lof-voted candidates
# score-using-embedding Time: 13.462864637374878s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.5739269256591797s
# compute-tf-idf-class_count Time: 15.579856395721436s
# compute-tf-idf-property_count Time: 16.740976810455322s
# context-match Time: 46.455708742141724s
# create-pseudo-gt Time: 0.00408482551574707s
#
# real	1m14.724s
# user	1m45.446s
# sys	0m3.079s
# 77694908_0_6083291340991074532.csv: 40 of 44
# align-page-rank Time: 1.8918766975402832s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 4.36161732673645s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 10.617260932922363s
# string-similarity-['jaro_winkler'] Time: 0.8205046653747559s
# string-similarity-['levenshtein'] Time: 4.64676308631897s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.19564390182495117s
# normalize-scores-des_cont_jaccard Time: 0.04848766326904297s
# smallest-qnode-number Time: 0.6329290866851807s
# mosaic-features Time: 0.021092891693115234s
# creat-singleton-feature Time: 0.2757902145385742s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 1.1223773956298828s
# Qnodes to lookup: 10760
# Qnodes from file: 10387
# Outlier removal generates 99 lof-voted candidates
# score-using-embedding Time: 31.497501611709595s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.6302452087402344s
# compute-tf-idf-class_count Time: 34.024964332580566s
# compute-tf-idf-property_count Time: 34.34642481803894s
# context-match Time: 53.901068925857544s
# create-pseudo-gt Time: 0.003999948501586914s
#
# real	1m40.881s
# user	2m10.799s
# sys	0m3.196s
# 50245608_0_871275842592178099.csv: 41 of 44
# align-page-rank Time: 4.305098295211792s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 15.580395698547363s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 22.10473656654358s
# string-similarity-['jaro_winkler'] Time: 2.3158695697784424s
# string-similarity-['levenshtein'] Time: 14.31022024154663s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.7259218692779541s
# normalize-scores-des_cont_jaccard Time: 0.15855050086975098s
# smallest-qnode-number Time: 2.788931131362915s
# mosaic-features Time: 0.055455684661865234s
# creat-singleton-feature Time: 0.7721292972564697s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.40404820442199707s
# Qnodes to lookup: 26520
# Qnodes from file: 25679
# _centroid_of_lof: Missing 1 of 267
# Outlier removal generates 160 lof-voted candidates
# score-using-embedding Time: 75.90112447738647s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 1.7002286911010742s
# compute-tf-idf-class_count Time: 80.99948501586914s
# compute-tf-idf-property_count Time: 82.7303671836853s
# context-match Time: 381.8787581920624s
# create-pseudo-gt Time: 0.0038177967071533203s
#
# real	7m58.476s
# user	8m27.239s
# sys	0m5.124s
# 40534006_0_4617468856744635526.csv: 42 of 44
# align-page-rank Time: 0.8605687618255615s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.718590497970581s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 1.5967061519622803s
# string-similarity-['jaro_winkler'] Time: 0.24414992332458496s
# string-similarity-['levenshtein'] Time: 0.8476569652557373s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.056140899658203125s
# normalize-scores-des_cont_jaccard Time: 0.021192312240600586s
# smallest-qnode-number Time: 0.19851374626159668s
# mosaic-features Time: 0.008558273315429688s
# creat-singleton-feature Time: 0.1183631420135498s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 1.0146403312683105s
# Qnodes to lookup: 4092
# Qnodes from file: 4034
# Outlier removal generates 25 lof-voted candidates
# score-using-embedding Time: 10.610099077224731s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.24909353256225586s
# compute-tf-idf-class_count Time: 12.085270643234253s
# compute-tf-idf-property_count Time: 12.244616031646729s
# context-match Time: 2.1420090198516846s
# create-pseudo-gt Time: 0.0066301822662353516s
#
# real	0m27.450s
# user	0m55.410s
# sys	0m2.985s
# 22864497_0_8632623712684511496.csv: 43 of 44
# align-page-rank Time: 5.400386571884155s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 18.429097652435303s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 26.4553005695343s
# string-similarity-['jaro_winkler'] Time: 2.9241862297058105s
# string-similarity-['levenshtein'] Time: 18.250672101974487s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.7267310619354248s
# normalize-scores-des_cont_jaccard Time: 0.13477325439453125s
# smallest-qnode-number Time: 3.8154571056365967s
# mosaic-features Time: 0.06398606300354004s
# creat-singleton-feature Time: 1.032851219177246s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.3952641487121582s
# Qnodes to lookup: 29456
# Qnodes from file: 28330
# Outlier removal generates 118 lof-voted candidates
# score-using-embedding Time: 91.21787858009338s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 2.0680387020111084s
# compute-tf-idf-class_count Time: 96.91081547737122s
# compute-tf-idf-property_count Time: 98.25010466575623s
# context-match Time: 218.3307797908783s
# create-pseudo-gt Time: 0.004305601119995117s
#
# real	5m32.485s
# user	6m2.447s
# sys	0m5.552s
# 24036779_0_5608105867560183058.csv: 44 of 44
# align-page-rank Time: 1.7668447494506836s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 7.830625295639038s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 8.120055437088013s
# string-similarity-['jaro_winkler'] Time: 2.3128840923309326s
# string-similarity-['levenshtein'] Time: 10.664984941482544s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.36190247535705566s
# normalize-scores-des_cont_jaccard Time: 0.06358575820922852s
# smallest-qnode-number Time: 0.6301870346069336s
# mosaic-features Time: 0.03316378593444824s
# creat-singleton-feature Time: 0.5912735462188721s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.4171314239501953s
# Qnodes to lookup: 13908
# Qnodes from file: 13592
# Outlier removal generates 117 lof-voted candidates
# score-using-embedding Time: 42.43373441696167s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.678337812423706s
# compute-tf-idf-class_count Time: 44.94190764427185s
# compute-tf-idf-property_count Time: 45.82071113586426s
# context-match Time: 179.05726623535156s
# create-pseudo-gt Time: 0.00474238395690918s
#
# real	3m57.849s
# user	4m28.370s
# sys	0m3.993s

# %%
feature_generation(dev_candidate_path, dev_graph_embedding, dev_class_count, dev_prop_count, dev_context_path, dev_feature_path)
# Out:
# 84575189_0_6365692015941409487.csv: 1 of 9
# align-page-rank Time: 1.8409578800201416s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 7.2447426319122314s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 10.854839086532593s
# string-similarity-['jaro_winkler'] Time: 0.9745080471038818s
# string-similarity-['levenshtein'] Time: 7.9472291469573975s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.10293197631835938s
# normalize-scores-des_cont_jaccard Time: 0.04551291465759277s
# smallest-qnode-number Time: 0.6154012680053711s
# mosaic-features Time: 0.02413797378540039s
# creat-singleton-feature Time: 0.31090474128723145s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 1.2024152278900146s
# Qnodes to lookup: 8486
# Qnodes from file: 7897
# Outlier removal generates 46 lof-voted candidates
# score-using-embedding Time: 37.1504967212677s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.6580898761749268s
# compute-tf-idf-class_count Time: 40.047500133514404s
# compute-tf-idf-property_count Time: 40.263389110565186s
# context-match Time: 1.2186222076416016s
# create-pseudo-gt Time: 0.004029989242553711s
#
# real	0m54.853s
# user	1m25.478s
# sys	0m3.147s
# 28086084_0_3127660530989916727.csv: 2 of 9
# align-page-rank Time: 3.944267749786377s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 10.063050508499146s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 37.74507975578308s
# string-similarity-['jaro_winkler'] Time: 3.495357036590576s
# string-similarity-['levenshtein'] Time: 14.091522693634033s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.5173699855804443s
# normalize-scores-des_cont_jaccard Time: 0.15859746932983398s
# smallest-qnode-number Time: 2.0175962448120117s
# mosaic-features Time: 0.04699826240539551s
# creat-singleton-feature Time: 0.8126311302185059s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 1.7885949611663818s
# Qnodes to lookup: 19531
# Qnodes from file: 19257
# Outlier removal generates 89 lof-voted candidates
# score-using-embedding Time: 86.77116870880127s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 1.373769760131836s
# compute-tf-idf-class_count Time: 91.53167247772217s
# compute-tf-idf-property_count Time: 92.61578917503357s
# context-match Time: 217.92387890815735s
# create-pseudo-gt Time: 0.0043675899505615234s
#
# real	5m24.793s
# user	5m53.420s
# sys	0m4.225s
# 50270082_0_444360818941411589.csv: 3 of 9
# align-page-rank Time: 1.5222251415252686s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 2.852111339569092s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 6.7636871337890625s
# string-similarity-['jaro_winkler'] Time: 0.7617294788360596s
# string-similarity-['levenshtein'] Time: 3.040572166442871s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.1446382999420166s
# normalize-scores-des_cont_jaccard Time: 0.06231498718261719s
# smallest-qnode-number Time: 1.2071716785430908s
# mosaic-features Time: 0.027158021926879883s
# creat-singleton-feature Time: 0.5037076473236084s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.3987710475921631s
# Qnodes to lookup: 16794
# Qnodes from file: 16683
# Outlier removal generates 50 lof-voted candidates
# score-using-embedding Time: 31.507181644439697s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.9287316799163818s
# compute-tf-idf-class_count Time: 34.4289870262146s
# compute-tf-idf-property_count Time: 35.131255865097046s
# context-match Time: 2.8860230445861816s
# create-pseudo-gt Time: 0.004053831100463867s
#
# real	0m52.430s
# user	1m20.679s
# sys	0m3.985s
# 29414811_2_4773219892816395776.csv: 4 of 9
# align-page-rank Time: 0.6049797534942627s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 1.0805537700653076s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 2.6959457397460938s
# string-similarity-['jaro_winkler'] Time: 0.16985869407653809s
# string-similarity-['levenshtein'] Time: 1.0598442554473877s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.042504072189331055s
# normalize-scores-des_cont_jaccard Time: 0.015624523162841797s
# smallest-qnode-number Time: 0.10821080207824707s
# mosaic-features Time: 0.0054302215576171875s
# creat-singleton-feature Time: 0.0567929744720459s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.33005619049072266s
# Qnodes to lookup: 2106
# Qnodes from file: 2025
# Outlier removal generates 22 lof-voted candidates
# score-using-embedding Time: 10.040541887283325s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.12959027290344238s
# compute-tf-idf-class_count Time: 10.715487957000732s
# compute-tf-idf-property_count Time: 11.320501804351807s
# context-match Time: 23.277947664260864s
# create-pseudo-gt Time: 0.003444194793701172s
#
# real	0m45.341s
# user	1m15.113s
# sys	0m2.763s
# 39759273_0_1427898308030295194.csv: 5 of 9
# align-page-rank Time: 1.9308557510375977s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 6.098484754562378s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 13.597191333770752s
# string-similarity-['jaro_winkler'] Time: 0.9434564113616943s
# string-similarity-['levenshtein'] Time: 5.744039058685303s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.23691034317016602s
# normalize-scores-des_cont_jaccard Time: 0.04798102378845215s
# smallest-qnode-number Time: 0.6344015598297119s
# mosaic-features Time: 0.031761884689331055s
# creat-singleton-feature Time: 0.2988247871398926s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.34969186782836914s
# Qnodes to lookup: 10448
# Qnodes from file: 10120
# Outlier removal generates 105 lof-voted candidates
# score-using-embedding Time: 36.63269352912903s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.5905168056488037s
# compute-tf-idf-class_count Time: 38.49972605705261s
# compute-tf-idf-property_count Time: 39.36116027832031s
# context-match Time: 56.4559063911438s
# create-pseudo-gt Time: 0.005496025085449219s
#
# real	1m48.972s
# user	2m19.056s
# sys	0m3.338s
# 14380604_4_3329235705746762392.csv: 6 of 9
# align-page-rank Time: 0.597581148147583s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.6743690967559814s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.7985672950744629s
# string-similarity-['jaro_winkler'] Time: 0.14389562606811523s
# string-similarity-['levenshtein'] Time: 0.6985363960266113s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.06280994415283203s
# normalize-scores-des_cont_jaccard Time: 0.015557289123535156s
# smallest-qnode-number Time: 0.10075521469116211s
# mosaic-features Time: 0.006019115447998047s
# creat-singleton-feature Time: 0.061502933502197266s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.34249091148376465s
# Qnodes to lookup: 2291
# Qnodes from file: 2226
# Outlier removal generates 9 lof-voted candidates
# score-using-embedding Time: 7.152173042297363s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.13177800178527832s
# compute-tf-idf-class_count Time: 8.005523920059204s
# compute-tf-idf-property_count Time: 8.181562185287476s
# context-match Time: 13.058216333389282s
# create-pseudo-gt Time: 0.0032150745391845703s
#
# real	0m32.771s
# user	1m2.884s
# sys	0m2.764s
# 14067031_0_559833072073397908.csv: 7 of 9
# align-page-rank Time: 0.9596638679504395s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 3.8410727977752686s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 3.7526419162750244s
# string-similarity-['jaro_winkler'] Time: 0.775482177734375s
# string-similarity-['levenshtein'] Time: 4.625465154647827s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.22585725784301758s
# normalize-scores-des_cont_jaccard Time: 0.03758049011230469s
# smallest-qnode-number Time: 0.30246782302856445s
# mosaic-features Time: 0.044544219970703125s
# creat-singleton-feature Time: 0.23575663566589355s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.37286853790283203s
# Qnodes to lookup: 7690
# Qnodes from file: 7433
# Outlier removal generates 59 lof-voted candidates
# score-using-embedding Time: 22.01423144340515s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.3661794662475586s
# compute-tf-idf-class_count Time: 23.149884462356567s
# compute-tf-idf-property_count Time: 24.01945424079895s
# context-match Time: 72.82507252693176s
# create-pseudo-gt Time: 0.004056453704833984s
#
# real	1m48.488s
# user	2m19.093s
# sys	0m3.286s
# 45073662_0_3179937335063201739.csv: 8 of 9
# align-page-rank Time: 0.5898759365081787s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 0.816213846206665s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 1.2436726093292236s
# string-similarity-['jaro_winkler'] Time: 0.14491987228393555s
# string-similarity-['levenshtein'] Time: 0.5499343872070312s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.034520864486694336s
# normalize-scores-des_cont_jaccard Time: 0.01978278160095215s
# smallest-qnode-number Time: 0.14263916015625s
# mosaic-features Time: 0.006395101547241211s
# creat-singleton-feature Time: 0.08200335502624512s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.3545186519622803s
# Qnodes to lookup: 3040
# Qnodes from file: 3004
# Outlier removal generates 7 lof-voted candidates
# score-using-embedding Time: 7.9886534214019775s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.1905980110168457s
# compute-tf-idf-class_count Time: 9.422906637191772s
# compute-tf-idf-property_count Time: 9.32459282875061s
# context-match Time: 0.6905219554901123s
# create-pseudo-gt Time: 0.005641937255859375s
#
# real	0m21.750s
# user	0m51.937s
# sys	0m2.688s
# 52299421_0_4473286348258170200.csv: 9 of 9
# align-page-rank Time: 1.415268898010254s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 6.227426528930664s
# string-similarity-['symmetric_monge_elkan:tokenizer=word'] Time: 8.219702005386353s
# string-similarity-['jaro_winkler'] Time: 1.4262964725494385s
# string-similarity-['levenshtein'] Time: 7.267973184585571s
# string-similarity-['jaccard:tokenizer=word'] Time: 0.4508986473083496s
# normalize-scores-des_cont_jaccard Time: 0.06186866760253906s
# smallest-qnode-number Time: 0.6613965034484863s
# mosaic-features Time: 0.03594684600830078s
# creat-singleton-feature Time: 0.35969996452331543s
# /home/sriamazingram/USC/Others/ISI/tl_env/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.24.1 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# vote-by-classifier Time: 0.35184264183044434s
# Qnodes to lookup: 15531
# Qnodes from file: 15218
# Outlier removal generates 87 lof-voted candidates
# score-using-embedding Time: 34.516112089157104s
# generate-reciprocal-rank-lof-graph-embedding-score Time: 0.7389914989471436s
# compute-tf-idf-class_count Time: 37.18945503234863s
# compute-tf-idf-property_count Time: 38.12437915802002s
# context-match Time: 117.06488394737244s
# create-pseudo-gt Time: 0.0041408538818359375s
#
# real	2m48.290s
# user	3m19.172s
# sys	0m3.330s

# %% [markdown]
# ### Generate Training Data

# %%
def merge_files(args):
    datapath = args.train_path
    eval_file_names = []
    for (dirpath, dirnames, filenames) in os.walk(datapath):
        for fn in filenames:
            if "csv" not in fn:
                continue
            abs_fn = f"{dirpath}/{fn}"
            assert os.path.isfile(abs_fn)
            if os.path.getsize(abs_fn) == 0:
                continue
            eval_file_names.append(abs_fn)
    df_list = []
    for fn in eval_file_names:
        fid = fn.split('/')[-1].split('.csv')[0]
        df = pd.read_csv(fn)
        df['table_id'] = fid
        df_list.append(df)
    return pd.concat(df_list) 

def compute_normalization_factor(args, all_data):
    min_max_scaler_path = args.min_max_scaler_path
    all_data_features = all_data[features]
    scaler = MinMaxScaler()
    scaler.fit(all_data_features)
    pickle.dump(scaler, open(min_max_scaler_path, 'wb'))
    return scaler

def generate_train_data(args):
    scaler_path = args.min_max_scaler_path
    scaler = pickle.load(open(scaler_path, 'rb'))
    final_list = []
    sfeatures = copy.deepcopy(features) + ['evaluation_label']
    print(sfeatures)
    normalize_features = features
    evaluation_label = ['evaluation_label']
    positive_features_final = []
    negative_features_final = []
    for i,file in enumerate(glob.glob(args.train_path + '/*.csv')):
        file_name = file.split('/')[-1]
        print(file_name)
        if os.path.getsize(file) == 0:
                continue
        d_sample = pd.read_csv(file)
#         grouped_obj = d_sample.groupby(['row', 'column'])
        grouped_obj = d_sample.groupby(['column', 'row'])
        for cell in grouped_obj:
            cell[1][normalize_features] = scaler.transform(cell[1][normalize_features])
            pos_features = []
            neg_features = []
            a = cell[1][cell[1]['evaluation_label'] == 1]
            if a.empty:
                continue
            num_rows = 64
            pos_row = a[sfeatures].drop('evaluation_label',axis=1)
            negatives_filtered = cell[1][cell[1]['evaluation_label'] == -1]
            sorted_df = negatives_filtered.sort_values('lof-graph-embedding-score',ascending=False)
            sorted_df = sorted_df[sfeatures]
            if 0 in sorted_df['evaluation_label'].tolist():
                continue
            if sorted_df.empty:
                continue
            neg_list = []
            if num_rows < len(sorted_df):
                sorted_df = sorted_df[sorted_df['evaluation_label'] == -1]
                neg_list.append(sorted_df[:2])
                retrieval_score_df = sorted_df[2:].sort_values('retrieval_score',ascending=False)
                neg_list.append(retrieval_score_df[:2])
                pagerank_score_df = retrieval_score_df[2:].sort_values('pagerank', ascending=False)
                neg_list.append(pagerank_score_df[:2])
                class_count_score_df = pagerank_score_df[2:].sort_values('lof_class_count_tf_idf_score', ascending=False)
                neg_list.append(class_count_score_df[:2])
                prop_count_score_df = class_count_score_df[2:].sort_values('lof_property_count_tf_idf_score', ascending=False)
                neg_list.append(prop_count_score_df[:2])
                monge_elkan_score_df = prop_count_score_df[2:].sort_values('monge_elkan', ascending=False)
                neg_list.append(monge_elkan_score_df[:2])
                monge_elkan_alias_score_df = monge_elkan_score_df[2:].sort_values('monge_elkan_aliases', ascending=False)
                neg_list.append(monge_elkan_alias_score_df[:2])
                
                context_score_df = monge_elkan_alias_score_df[2:].sort_values('context_score', ascending=False)
                neg_list.append(context_score_df[:2])

                jaro_winkler_score_df = monge_elkan_alias_score_df[2:].sort_values('jaro_winkler', ascending=False)
                neg_list.append(jaro_winkler_score_df[:2])
                
                top_sample_df = jaro_winkler_score_df.sample(n=50)
                neg_list.append(top_sample_df)
                top_sample_df = pd.concat(neg_list)
                top_sample_df.drop('evaluation_label', inplace=True, axis=1)
                top_sample_arr = top_sample_df.to_numpy()

            for i in range(len(top_sample_arr)):
                neg_features.append(top_sample_arr[i])
            random.shuffle(neg_features)
            for i in range(len(top_sample_arr)):
                pos_row_sample = pos_row.sample(n=1)
                ar = pos_row_sample.to_numpy()
                for ps_ar in ar:
                    pos_features.append(ps_ar)
            positive_features_final.append(pos_features)
            negative_features_final.append(neg_features)
    print(len(positive_features_final), len(positive_features_final[37]))
    print(len(negative_features_final), len(negative_features_final[37]))
    pickle.dump(positive_features_final,open(args.pos_output,'wb'))
    pickle.dump(negative_features_final,open(args.neg_output,'wb'))

# %%
gen_training_data_args = Namespace(train_path=train_feature_path, pos_output=pos_output, neg_output=neg_output, 
                 min_max_scaler_path=min_max_scaler_path)
all_data = merge_files(gen_training_data_args)
scaler = compute_normalization_factor(gen_training_data_args, all_data)
generate_train_data(gen_training_data_args)
# Out:
# ['pagerank', 'retrieval_score', 'monge_elkan', 'monge_elkan_aliases', 'des_cont_jaccard', 'jaro_winkler', 'levenshtein', 'singleton', 'num_char', 'num_tokens', 'lof_class_count_tf_idf_score', 'lof_property_count_tf_idf_score', 'lof-graph-embedding-score', 'lof-reciprocal-rank', 'context_score', 'pseudo_gt', 'evaluation_label']
# 37856682_0_6818907050314633217.csv
# 38428277_0_1311643810102462607.csv
# 29414811_12_251152470253168163.csv
# 9834884_0_3871985887467090123.csv
# 21245481_0_8730460088443117515.csv
# 39650055_5_7135804139753401681.csv
# 53989675_0_8697482470743954630.csv
# 99070098_0_2074872741302696997.csv
# 46671561_0_6122315295162029872.csv
# 80588006_0_6965325215443683359.csv
# 20135078_0_7570343137119682530.csv
# 39107734_2_2329160387535788734.csv
# 58891288_0_1117541047012405958.csv
# 84548468_0_5955155464119382182.csv
# 16767252_0_2409448375013995751.csv
# 88523363_0_8180214313099580515.csv
# 69537082_0_7789694313271016902.csv
# 33401079_0_9127583903019856402.csv
# 1438042989043_35_20150728002309-00287-ip-10-236-191-2_875026214_2.csv
# 26310680_0_5150772059999313798.csv
# 60319454_0_3938426910282115527.csv
# 91959037_0_7907661684242014480.csv
# 9567241_0_5666388268510912770.csv
# 21362676_0_6854186738074119688.csv
# 54719588_0_8417197176086756912.csv
# 1438042986423_95_20150728002306-00125-ip-10-236-191-2_88435628_5.csv
# 43237185_1_3636357855502246981.csv
# 29414811_13_8724394428539174350.csv
# 53822652_0_5767892317858575530.csv
# 41480166_0_6681239260286218499.csv
# 71840765_0_6664391841933033844.csv
# 63450419_0_8012592961815711786.csv
# 35188621_0_6058553107571275232.csv
# 25404227_0_2240631045609013057.csv
# 90196673_0_5458330029110291950.csv
# 39173938_0_7916056990138658530.csv
# 10579449_0_1681126353774891032.csv
# 1438042989018_40_20150728002309-00067-ip-10-236-191-2_57714692_2.csv
# 8468806_0_4382447409703007384.csv
# 77694908_0_6083291340991074532.csv
# 50245608_0_871275842592178099.csv
# 40534006_0_4617468856744635526.csv
# 22864497_0_8632623712684511496.csv
# 24036779_0_5608105867560183058.csv
# 5621 68
# 5621 68

# %% [markdown]
# ### Model Definition

# %%
# Dataset
class T2DV2Dataset(Dataset):
    def __init__(self, pos_features, neg_features):
        self.pos_features = pos_features
        self.neg_features = neg_features
    
    def __len__(self):
        return len(self.pos_features)
    
    def __getitem__(self, idx):
        return self.pos_features[idx], self.neg_features[idx]

# Model
class PairwiseNetwork(nn.Module):
    def __init__(self, hidden_size):
        super().__init__()
        #original 12x24, 24x12, 12x12, 12x1
        self.fc1 = nn.Linear(hidden_size, 2*hidden_size)
        self.fc2 = nn.Linear(2*hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, hidden_size)
        self.fc4 = nn.Linear(hidden_size, 1)
    
    def forward(self, pos_features, neg_features):
        # Positive pass
        x = F.relu(self.fc1(pos_features))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        pos_out = torch.sigmoid(self.fc4(x))
        
        # Negative Pass
        x = F.relu(self.fc1(neg_features))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        neg_out = torch.sigmoid(self.fc4(x))
        
        return pos_out, neg_out
    
    def predict(self, test_feat):
        x = F.relu(self.fc1(test_feat))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        test_out = torch.sigmoid(self.fc4(x))
        return test_out

# Pairwise Loss
class PairwiseLoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.m = 0
    
    def forward(self, pos_out, neg_out):
        distance = (1 - pos_out) + neg_out
        loss = torch.mean(torch.max(torch.tensor(0), distance))
        return loss

# %% [markdown]
# ### Training

# %%
def generate_dataloader(positive_feat_path, negative_feat_path):
    pos_features = pickle.load(open(positive_feat_path, 'rb'))
    neg_features = pickle.load(open(negative_feat_path, 'rb'))

    pos_features_flatten = list(chain.from_iterable(pos_features))
    neg_features_flatten = list(chain.from_iterable(neg_features))

    train_dataset = T2DV2Dataset(pos_features_flatten, neg_features_flatten)
    train_dataloader = DataLoader(train_dataset, batch_size=64)
    return train_dataloader

def infer_scores(min_max_scaler_path, input_table_path, output_table_path, model):
    scaler = pickle.load(open(min_max_scaler_path, 'rb'))
    normalize_features = features
    for file in glob.glob(input_table_path + '/*.csv'):
        file_name = file.split('/')[-1]
        if os.path.getsize(file) == 0:
                continue
        if file_name != '52299421_0_4473286348258170200.csv':
            print(file_name)
            d_sample = pd.read_csv(file)
            grouped_obj = d_sample.groupby(['column', 'row'])
            new_df_list = []
            pred = []
            for cell in grouped_obj:
                cell[1][normalize_features] = scaler.transform(cell[1][normalize_features])
                sorted_df = cell[1].sort_values('lof-graph-embedding-score',ascending=False)[:64]
                sorted_df_features = sorted_df[normalize_features]
                new_df_list.append(sorted_df)
                arr = sorted_df_features.to_numpy()
                test_inp = []
                for a in arr:
                    test_inp.append(a)
                test_tensor = torch.tensor(test_inp).float()
                scores = model.predict(test_tensor)
                pred.extend(torch.squeeze(scores).tolist())
            test_df = pd.concat(new_df_list)
            test_df[final_score_column] = pred
            test_df.to_csv(f"{output_table_path}/{file_name}", index=False)

def train(args):
    if torch.cuda.is_available():
        device = torch.device('cuda')
    
    else:
        device = torch.device('cpu')
    train_dataloader = generate_dataloader(args.positive_feat_path, args.negative_feat_path)
    criterion = PairwiseLoss()
    EPOCHS = args.num_epochs
    model = PairwiseNetwork(len(features)).to(device=device)
    optimizer = Adam(model.parameters(), lr=args.lr)
    top1_max_prec = 0
    for epoch in range(EPOCHS):
        train_epoch_loss = 0
        avg_loss = 0
        model.train()
        for bid, batch in tqdm(enumerate(train_dataloader), position=0, leave=True):
            positive_feat = torch.tensor(batch[0].float())
            negative_feat = torch.tensor(batch[1].float())
            optimizer.zero_grad()
            pos_out, neg_out = model(positive_feat, negative_feat)
            loss = criterion(pos_out, neg_out)
            loss.backward()
            optimizer.step()
            train_epoch_loss += loss
        avg_loss = train_epoch_loss / bid

        # Evaluation
        model.eval()
        infer_scores(args.min_max_scaler_path, args.dev_path, args.dev_output, model)
        eval_data = merge_eval_files(args.dev_output)
        res, candidate_eval_data = parse_eval_files_stats(eval_data, final_score_column)
        top1_precision = res['num_tasks_with_model_score_top_one_accurate']/res['num_tasks_with_gt']
        if top1_precision > top1_max_prec:
            top1_max_prec = top1_precision
            model_save_name = 'epoch_{}_loss_{}_top1_{}.pth'.format(epoch, avg_loss, top1_max_prec)
            best_model_path = os.path.join(args.model_save_path, model_save_name)
            torch.save(model.state_dict(), best_model_path)
        
        print("Epoch {}, Avg Loss is {}, epoch top1 {}, max top1 {}".format(epoch, avg_loss, top1_precision, top1_max_prec))
    return best_model_path

# %%
def merge_eval_files(final_score_path):
    eval_file_names = []
    df_list = []
    for (dirpath, dirnames, filenames) in os.walk(final_score_path):
        for fn in filenames:
            if fn != '52299421_0_4473286348258170200.csv':
                if "csv" not in fn:
                    continue
                abs_fn = os.path.join(dirpath, fn)
                assert os.path.isfile(abs_fn)
                if os.path.getsize(abs_fn) == 0:
                    continue
                eval_file_names.append(abs_fn)
    
    for fn in eval_file_names:
        fid = fn.split('/')[-1].split('.csv')[0]
        df = pd.read_csv(fn)
        df['table_id'] = fid
        # df = df.fillna('')
        df_list.append(df)
    return pd.concat(df_list)

def parse_eval_files_stats(eval_data, method):
    res = {}
    candidate_eval_data = eval_data.groupby(['table_id', 'column', 'row'])['table_id'].count().reset_index(name="count")
    res['num_tasks'] = len(eval_data.groupby(['table_id', 'column', 'row']))
    res['num_tasks_with_gt'] = len(eval_data[pd.notna(eval_data['GT_kg_id'])].groupby(['table_id', 'column', 'row']))
    res['num_tasks_with_gt_in_candidate'] = len(eval_data[eval_data['evaluation_label'] == 1].groupby(['table_id', 'column', 'row']))
    res['num_tasks_with_singleton_candidate'] = len(candidate_eval_data[candidate_eval_data['count'] == 1].groupby(['table_id', 'column', 'row']))
    singleton_eval_data = candidate_eval_data[candidate_eval_data['count'] == 1]
    num_tasks_with_singleton_candidate_with_gt = 0
    for i, row in singleton_eval_data.iterrows():
        table_id, row_idx, col_idx = row['table_id'], row['row'], row['column']
        c_e_data = eval_data[(eval_data['table_id'] == table_id) & (eval_data['row'] == row_idx) & (eval_data['column'] == col_idx)]
        assert len(c_e_data) == 1
        if c_e_data.iloc[0]['evaluation_label'] == 1:
            num_tasks_with_singleton_candidate_with_gt += 1
    res['num_tasks_with_singleton_candidate_with_gt'] = num_tasks_with_singleton_candidate_with_gt
    num_tasks_with_graph_top_one_accurate = []
    num_tasks_with_graph_top_five_accurate = []
    num_tasks_with_graph_top_ten_accurate = []
    num_tasks_with_model_score_top_one_accurate = []
    num_tasks_with_model_score_top_five_accurate = []
    num_tasks_with_model_score_top_ten_accurate = []
    has_gt_list = []
    has_gt_in_candidate = []
    # candidate_eval_data = candidate_eval_data[:1]
    for i, row in candidate_eval_data.iterrows():
        #print(i)
        table_id, row_idx, col_idx = row['table_id'], row['row'], row['column']
        c_e_data = eval_data[(eval_data['table_id'] == table_id) & (eval_data['row'] == row_idx) & (eval_data['column'] == col_idx)]
        assert len(c_e_data) > 0
        if np.nan not in set(c_e_data['GT_kg_id']):
            has_gt_list.append(1)
        else:
            has_gt_list.append(0)
        if 1 in set(c_e_data['evaluation_label']):
            has_gt_in_candidate.append(1)
        else:
            has_gt_in_candidate.append(0)
            
        # handle graph-embedding-score
        s_data = c_e_data.sort_values(by=['lof-graph-embedding-score'], ascending=False)
        if s_data.iloc[0]['evaluation_label'] == 1:
            num_tasks_with_graph_top_one_accurate.append(1)
        else:
            num_tasks_with_graph_top_one_accurate.append(0)
        if 1 in set(s_data.iloc[0:5]['evaluation_label']):
            num_tasks_with_graph_top_five_accurate.append(1)
        else:
            num_tasks_with_graph_top_five_accurate.append(0)
        if 1 in set(s_data.iloc[0:10]['evaluation_label']):
            num_tasks_with_graph_top_ten_accurate.append(1)
        else:
            num_tasks_with_graph_top_ten_accurate.append(0)
        
        #rank on model score
        s_data = c_e_data.sort_values(by=[method], ascending=False)
        if s_data.iloc[0]['evaluation_label'] == 1:
            num_tasks_with_model_score_top_one_accurate.append(1)
        else:
            num_tasks_with_model_score_top_one_accurate.append(0)
        if 1 in set(s_data.iloc[0:5]['evaluation_label']):
            num_tasks_with_model_score_top_five_accurate.append(1)
        else:
            num_tasks_with_model_score_top_five_accurate.append(0)
        if 1 in set(s_data.iloc[0:10]['evaluation_label']):
            num_tasks_with_model_score_top_ten_accurate.append(1)
        else:
            num_tasks_with_model_score_top_ten_accurate.append(0)
            
        cf_e_data = c_e_data.copy()
        cf_e_data['lof-graph-embedding-score'] = cf_e_data['lof-graph-embedding-score'].replace(np.nan, 0)
        cf_e_data[method] = cf_e_data[method].replace(np.nan, 0)

    candidate_eval_data['lof-graph_top_one_accurate'] = num_tasks_with_graph_top_one_accurate
    candidate_eval_data['lof-graph_top_five_accurate'] = num_tasks_with_graph_top_five_accurate
    candidate_eval_data['lof-graph_top_ten_accurate'] = num_tasks_with_graph_top_five_accurate
    candidate_eval_data['model_top_one_accurate'] = num_tasks_with_model_score_top_one_accurate
    candidate_eval_data['model_top_five_accurate'] = num_tasks_with_model_score_top_five_accurate
    candidate_eval_data['model_top_ten_accurate'] = num_tasks_with_model_score_top_ten_accurate
    candidate_eval_data['has_gt'] = has_gt_list
    candidate_eval_data['has_gt_in_candidate'] = has_gt_in_candidate
    res['num_tasks_with_graph_top_one_accurate'] = sum(num_tasks_with_graph_top_one_accurate)
    res['num_tasks_with_graph_top_five_accurate'] = sum(num_tasks_with_graph_top_five_accurate)
    res['num_tasks_with_graph_top_ten_accurate'] = sum(num_tasks_with_graph_top_ten_accurate)
    res['num_tasks_with_model_score_top_one_accurate'] = sum(num_tasks_with_model_score_top_one_accurate)
    res['num_tasks_with_model_score_top_five_accurate'] = sum(num_tasks_with_model_score_top_five_accurate)
    res['num_tasks_with_model_score_top_ten_accurate'] = sum(num_tasks_with_model_score_top_ten_accurate)
    return res, candidate_eval_data

# %%
training_args = Namespace(num_epochs=20, lr=0.001, positive_feat_path=pos_output, negative_feat_path=neg_output,
                         dev_path=dev_feature_path, dev_output=dev_output_predictions,
                         model_save_path=model_save_path, min_max_scaler_path=min_max_scaler_path)

# %%
## Call Training
best_model_path = train(training_args)
# Out:
# 0it [00:00, ?it/s]<ipython-input-15-7a187275f3b9>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch[0].float())
# <ipython-input-15-7a187275f3b9>:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch[1].float())
# 5973it [00:15, 382.01it/s]
# 84575189_0_6365692015941409487.csv
# 28086084_0_3127660530989916727.csv
# 50270082_0_444360818941411589.csv
# 29414811_2_4773219892816395776.csv
# 39759273_0_1427898308030295194.csv
# 14380604_4_3329235705746762392.csv
# 14067031_0_559833072073397908.csv
# 45073662_0_3179937335063201739.csv
# 0it [00:00, ?it/s]<ipython-input-15-7a187275f3b9>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch[0].float())
# <ipython-input-15-7a187275f3b9>:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch[1].float())
# 51it [00:00, 505.17it/s]
# Epoch 0, Avg Loss is 0.12168200314044952, epoch top1 0.8870056497175142, max top1 0.8870056497175142
# 5973it [00:10, 543.81it/s]
# 84575189_0_6365692015941409487.csv
# 28086084_0_3127660530989916727.csv
# 50270082_0_444360818941411589.csv
# 29414811_2_4773219892816395776.csv
# 39759273_0_1427898308030295194.csv
# 14380604_4_3329235705746762392.csv
# 14067031_0_559833072073397908.csv
# 45073662_0_3179937335063201739.csv
# 0it [00:00, ?it/s]<ipython-input-15-7a187275f3b9>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch[0].float())
# <ipython-input-15-7a187275f3b9>:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch[1].float())
# 54it [00:00, 535.82it/s]
# Epoch 1, Avg Loss is 0.09006624668836594, epoch top1 0.9110169491525424, max top1 0.9110169491525424
# 5973it [00:09, 610.35it/s]
# 84575189_0_6365692015941409487.csv
# 28086084_0_3127660530989916727.csv
# 50270082_0_444360818941411589.csv
# 29414811_2_4773219892816395776.csv
# 39759273_0_1427898308030295194.csv
# 14380604_4_3329235705746762392.csv
# 14067031_0_559833072073397908.csv
# 45073662_0_3179937335063201739.csv
# 0it [00:00, ?it/s]<ipython-input-15-7a187275f3b9>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch[0].float())
# <ipython-input-15-7a187275f3b9>:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch[1].float())
# 54it [00:00, 536.86it/s]
# Epoch 2, Avg Loss is 0.08523514866828918, epoch top1 0.846045197740113, max top1 0.9110169491525424
# 5973it [00:09, 613.21it/s]
# 84575189_0_6365692015941409487.csv
# 28086084_0_3127660530989916727.csv
# 50270082_0_444360818941411589.csv
# 29414811_2_4773219892816395776.csv
# 39759273_0_1427898308030295194.csv
# 14380604_4_3329235705746762392.csv
# 14067031_0_559833072073397908.csv
# 45073662_0_3179937335063201739.csv
# 0it [00:00, ?it/s]<ipython-input-15-7a187275f3b9>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch[0].float())
# <ipython-input-15-7a187275f3b9>:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch[1].float())
# 51it [00:00, 509.23it/s]
# Epoch 3, Avg Loss is 0.08374599367380142, epoch top1 0.8050847457627118, max top1 0.9110169491525424
# 5973it [00:09, 617.68it/s]
# 84575189_0_6365692015941409487.csv
# 28086084_0_3127660530989916727.csv
# 50270082_0_444360818941411589.csv
# 29414811_2_4773219892816395776.csv
# 39759273_0_1427898308030295194.csv
# 14380604_4_3329235705746762392.csv
# 14067031_0_559833072073397908.csv
# 45073662_0_3179937335063201739.csv
# 0it [00:00, ?it/s]<ipython-input-15-7a187275f3b9>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch[0].float())
# <ipython-input-15-7a187275f3b9>:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch[1].float())
# 52it [00:00, 515.25it/s]
# Epoch 4, Avg Loss is 0.08500885963439941, epoch top1 0.8121468926553672, max top1 0.9110169491525424
# 5973it [00:10, 586.52it/s]
# 84575189_0_6365692015941409487.csv
# 28086084_0_3127660530989916727.csv
# 50270082_0_444360818941411589.csv
# 29414811_2_4773219892816395776.csv
# 39759273_0_1427898308030295194.csv
# 14380604_4_3329235705746762392.csv
# 14067031_0_559833072073397908.csv
# 45073662_0_3179937335063201739.csv
# 0it [00:00, ?it/s]
# Epoch 5, Avg Loss is 0.0799228698015213, epoch top1 0.7175141242937854, max top1 0.9110169491525424
# <ipython-input-15-7a187275f3b9>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch[0].float())
# <ipython-input-15-7a187275f3b9>:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch[1].float())
# 5973it [00:09, 613.26it/s]
# 84575189_0_6365692015941409487.csv
# 28086084_0_3127660530989916727.csv
# 50270082_0_444360818941411589.csv
# 29414811_2_4773219892816395776.csv
# 39759273_0_1427898308030295194.csv
# 14380604_4_3329235705746762392.csv
# 14067031_0_559833072073397908.csv
# 45073662_0_3179937335063201739.csv
# 0it [00:00, ?it/s]
# Epoch 6, Avg Loss is 0.07955721765756607, epoch top1 0.5805084745762712, max top1 0.9110169491525424
# <ipython-input-15-7a187275f3b9>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch[0].float())
# <ipython-input-15-7a187275f3b9>:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch[1].float())
# 5973it [00:09, 615.90it/s]
# 84575189_0_6365692015941409487.csv
# 28086084_0_3127660530989916727.csv
# 50270082_0_444360818941411589.csv
# 29414811_2_4773219892816395776.csv
# 39759273_0_1427898308030295194.csv
# 14380604_4_3329235705746762392.csv
# 14067031_0_559833072073397908.csv
# 45073662_0_3179937335063201739.csv
# 0it [00:00, ?it/s]
# Epoch 7, Avg Loss is 0.08696103096008301, epoch top1 0.768361581920904, max top1 0.9110169491525424
# <ipython-input-15-7a187275f3b9>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch[0].float())
# <ipython-input-15-7a187275f3b9>:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch[1].float())
# 5973it [00:09, 602.25it/s]
# 84575189_0_6365692015941409487.csv
# 28086084_0_3127660530989916727.csv
# 50270082_0_444360818941411589.csv
# 29414811_2_4773219892816395776.csv
# 39759273_0_1427898308030295194.csv
# 14380604_4_3329235705746762392.csv
# 14067031_0_559833072073397908.csv
# 45073662_0_3179937335063201739.csv
# 0it [00:00, ?it/s]<ipython-input-15-7a187275f3b9>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch[0].float())
# <ipython-input-15-7a187275f3b9>:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch[1].float())
# 52it [00:00, 517.20it/s]
# Epoch 8, Avg Loss is 0.08515159785747528, epoch top1 0.6793785310734464, max top1 0.9110169491525424
# 5973it [00:09, 609.80it/s]
# 84575189_0_6365692015941409487.csv
# 28086084_0_3127660530989916727.csv
# 50270082_0_444360818941411589.csv
# 29414811_2_4773219892816395776.csv
# 39759273_0_1427898308030295194.csv
# 14380604_4_3329235705746762392.csv
# 14067031_0_559833072073397908.csv
# 45073662_0_3179937335063201739.csv
# 0it [00:00, ?it/s]<ipython-input-15-7a187275f3b9>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch[0].float())
# <ipython-input-15-7a187275f3b9>:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch[1].float())
# 53it [00:00, 523.63it/s]
# Epoch 9, Avg Loss is 0.0814913809299469, epoch top1 0.7372881355932204, max top1 0.9110169491525424
# 5973it [00:09, 615.22it/s]
# 84575189_0_6365692015941409487.csv
# 28086084_0_3127660530989916727.csv
# 50270082_0_444360818941411589.csv
# 29414811_2_4773219892816395776.csv
# 39759273_0_1427898308030295194.csv
# 14380604_4_3329235705746762392.csv
# 14067031_0_559833072073397908.csv
# 45073662_0_3179937335063201739.csv
# 0it [00:00, ?it/s]<ipython-input-15-7a187275f3b9>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch[0].float())
# <ipython-input-15-7a187275f3b9>:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch[1].float())
# 53it [00:00, 527.11it/s]
# Epoch 10, Avg Loss is 0.0800306499004364, epoch top1 0.7612994350282486, max top1 0.9110169491525424
# 5973it [00:09, 600.38it/s]
# 84575189_0_6365692015941409487.csv
# 28086084_0_3127660530989916727.csv
# 50270082_0_444360818941411589.csv
# 29414811_2_4773219892816395776.csv
# 39759273_0_1427898308030295194.csv
# 14380604_4_3329235705746762392.csv
# 14067031_0_559833072073397908.csv
# 45073662_0_3179937335063201739.csv
# 0it [00:00, ?it/s]<ipython-input-15-7a187275f3b9>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch[0].float())
# <ipython-input-15-7a187275f3b9>:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch[1].float())
# 51it [00:00, 506.43it/s]
# Epoch 11, Avg Loss is 0.08220110833644867, epoch top1 0.4533898305084746, max top1 0.9110169491525424
# 5973it [00:09, 604.63it/s]
# 84575189_0_6365692015941409487.csv
# 28086084_0_3127660530989916727.csv
# 50270082_0_444360818941411589.csv
# 29414811_2_4773219892816395776.csv
# 39759273_0_1427898308030295194.csv
# 14380604_4_3329235705746762392.csv
# 14067031_0_559833072073397908.csv
# 45073662_0_3179937335063201739.csv
# 0it [00:00, ?it/s]<ipython-input-15-7a187275f3b9>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch[0].float())
# <ipython-input-15-7a187275f3b9>:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch[1].float())
# 52it [00:00, 516.07it/s]
# Epoch 12, Avg Loss is 0.08605607599020004, epoch top1 0.4788135593220339, max top1 0.9110169491525424
# 5973it [00:09, 603.30it/s]
# 84575189_0_6365692015941409487.csv
# 28086084_0_3127660530989916727.csv
# 50270082_0_444360818941411589.csv
# 29414811_2_4773219892816395776.csv
# 39759273_0_1427898308030295194.csv
# 14380604_4_3329235705746762392.csv
# 14067031_0_559833072073397908.csv
# 45073662_0_3179937335063201739.csv
# 0it [00:00, ?it/s]<ipython-input-15-7a187275f3b9>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch[0].float())
# <ipython-input-15-7a187275f3b9>:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch[1].float())
# 51it [00:00, 508.69it/s]
# Epoch 13, Avg Loss is 0.0884942039847374, epoch top1 0.7853107344632768, max top1 0.9110169491525424
# 5973it [00:09, 604.69it/s]
# 84575189_0_6365692015941409487.csv
# 28086084_0_3127660530989916727.csv
# 50270082_0_444360818941411589.csv
# 29414811_2_4773219892816395776.csv
# 39759273_0_1427898308030295194.csv
# 14380604_4_3329235705746762392.csv
# 14067031_0_559833072073397908.csv
# 45073662_0_3179937335063201739.csv
# 0it [00:00, ?it/s]<ipython-input-15-7a187275f3b9>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch[0].float())
# <ipython-input-15-7a187275f3b9>:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch[1].float())
# 53it [00:00, 522.68it/s]
# Epoch 14, Avg Loss is 0.08723536878824234, epoch top1 0.7612994350282486, max top1 0.9110169491525424
# 5973it [00:10, 596.19it/s]
# 84575189_0_6365692015941409487.csv
# 28086084_0_3127660530989916727.csv
# 50270082_0_444360818941411589.csv
# 29414811_2_4773219892816395776.csv
# 39759273_0_1427898308030295194.csv
# 14380604_4_3329235705746762392.csv
# 14067031_0_559833072073397908.csv
# 45073662_0_3179937335063201739.csv
# 0it [00:00, ?it/s]<ipython-input-15-7a187275f3b9>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch[0].float())
# <ipython-input-15-7a187275f3b9>:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch[1].float())
# 52it [00:00, 514.86it/s]
# Epoch 15, Avg Loss is 0.08647142350673676, epoch top1 0.6129943502824858, max top1 0.9110169491525424
# 5973it [00:09, 605.40it/s]
# 84575189_0_6365692015941409487.csv
# 28086084_0_3127660530989916727.csv
# 50270082_0_444360818941411589.csv
# 29414811_2_4773219892816395776.csv
# 39759273_0_1427898308030295194.csv
# 14380604_4_3329235705746762392.csv
# 14067031_0_559833072073397908.csv
# 45073662_0_3179937335063201739.csv
# 0it [00:00, ?it/s]<ipython-input-15-7a187275f3b9>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch[0].float())
# <ipython-input-15-7a187275f3b9>:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch[1].float())
# 52it [00:00, 512.45it/s]
# Epoch 16, Avg Loss is 0.0812574252486229, epoch top1 0.768361581920904, max top1 0.9110169491525424
# 5973it [00:09, 607.16it/s]
# 84575189_0_6365692015941409487.csv
# 28086084_0_3127660530989916727.csv
# 50270082_0_444360818941411589.csv
# 29414811_2_4773219892816395776.csv
# 39759273_0_1427898308030295194.csv
# 14380604_4_3329235705746762392.csv
# 14067031_0_559833072073397908.csv
# 45073662_0_3179937335063201739.csv
# 0it [00:00, ?it/s]<ipython-input-15-7a187275f3b9>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch[0].float())
# <ipython-input-15-7a187275f3b9>:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch[1].float())
# 50it [00:00, 496.51it/s]
# Epoch 17, Avg Loss is 0.08396260440349579, epoch top1 0.6680790960451978, max top1 0.9110169491525424
# 5973it [00:10, 581.17it/s]
# 84575189_0_6365692015941409487.csv
# 28086084_0_3127660530989916727.csv
# 50270082_0_444360818941411589.csv
# 29414811_2_4773219892816395776.csv
# 39759273_0_1427898308030295194.csv
# 14380604_4_3329235705746762392.csv
# 14067031_0_559833072073397908.csv
# 45073662_0_3179937335063201739.csv
# 0it [00:00, ?it/s]
# Epoch 18, Avg Loss is 0.09217099845409393, epoch top1 0.7245762711864406, max top1 0.9110169491525424
# <ipython-input-15-7a187275f3b9>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_feat = torch.tensor(batch[0].float())
# <ipython-input-15-7a187275f3b9>:59: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_feat = torch.tensor(batch[1].float())
# 5973it [00:10, 596.30it/s]
# 84575189_0_6365692015941409487.csv
# 28086084_0_3127660530989916727.csv
# 50270082_0_444360818941411589.csv
# 29414811_2_4773219892816395776.csv
# 39759273_0_1427898308030295194.csv
# 14380604_4_3329235705746762392.csv
# 14067031_0_559833072073397908.csv
# 45073662_0_3179937335063201739.csv
# Epoch 19, Avg Loss is 0.08728277683258057, epoch top1 0.6991525423728814, max top1 0.9110169491525424

# %%
best_model_path
# Out:
# '/home/sriamazingram/USC/Others/ISI/data/t2dv2/dev-output/8_1/saved_models/epoch_1_loss_0.09006624668836594_top1_0.9110169491525424.pth'

# %% [markdown]
# ## Dev Prediction

# %%
def dev_prediction(dev_feature_path, dev_predictions_top_k, saved_model, output_column, min_max_scaler_path, k=5):
    for file in glob.glob(dev_feature_path + '/*.csv'):
        filename = file.split("/")[-1]
        print(filename)
        feature_str =  ",".join(features)
        if os.path.getsize(file) == 0:
                    continue
        # location where the output generated by the predictions wil be stored.
        dev_output = f"{dev_predictions_top_k}/{filename}"
        # !tl predict-using-model $file -o $output_column \
            --features $feature_str \
            --ranking-model $saved_model \
            --normalization-factor $min_max_scaler_path \
            / get-kg-links -c $output_column -k $k --k-rows \
            > $dev_output

# %%
def add_color(dev_predictions_top_k, dev_colorized_path, score_column, k=5):
    for file in glob.glob(dev_predictions_top_k + '/*.csv'):
        filename = file.split("/")[-1]
        print(filename)
        if os.path.getsize(file) == 0:
                    continue
                
        dev_color_file = f"{dev_colorized_path}/{filename.strip('.csv')}.xlsx"
        # !tl add-color $file -c "$score_column,evaluation_label" -k $k --output $dev_color_file

# %%
def compute_metrics(dev_predictions_top_k, dev_predictions_metrics, score_column, k=5):
    df_list = []
    for file in glob.glob(dev_predictions_top_k + '/*.csv'):
        filename = file.split("/")[-1]
        print(filename)
        if os.path.getsize(file) == 0:
                    continue
                
        dev_metrics_file = f"{dev_predictions_metrics}/{filename}"
        # !tl metrics $file -k $k -c $score_column --tag $filename> $dev_metrics_file
        df_list.append(pd.read_csv(dev_metrics_file))
    return pd.concat(df_list)

# %%
dev_prediction(dev_feature_path, dev_predictions_top_k, best_model_path, final_score_column, min_max_scaler_path, k=200)
# Out:
# 84575189_0_6365692015941409487.csv
# predict-using-model Time: 6.13994574546814s
# get-kg-links-siamese_prediction Time: 1.1168434619903564s
# 28086084_0_3127660530989916727.csv
# predict-using-model Time: 2.1349174976348877s
# get-kg-links-siamese_prediction Time: 2.3903934955596924s
# 50270082_0_444360818941411589.csv
# predict-using-model Time: 1.5177969932556152s
# get-kg-links-siamese_prediction Time: 1.7700471878051758s
# 29414811_2_4773219892816395776.csv
# predict-using-model Time: 0.48032307624816895s
# get-kg-links-siamese_prediction Time: 0.23757243156433105s
# 39759273_0_1427898308030295194.csv
# predict-using-model Time: 1.0865421295166016s
# get-kg-links-siamese_prediction Time: 1.0333786010742188s
# 14380604_4_3329235705746762392.csv
# predict-using-model Time: 0.45293116569519043s
# get-kg-links-siamese_prediction Time: 0.22068047523498535s
# 14067031_0_559833072073397908.csv
# predict-using-model Time: 0.7280888557434082s
# get-kg-links-siamese_prediction Time: 0.6941039562225342s
# 45073662_0_3179937335063201739.csv
# predict-using-model Time: 0.5092294216156006s
# get-kg-links-siamese_prediction Time: 0.3420398235321045s
# 52299421_0_4473286348258170200.csv
# predict-using-model Time: 1.0782034397125244s
# get-kg-links-siamese_prediction Time: 1.2227349281311035s

# %%
metrics_df = compute_metrics(dev_predictions_top_k, dev_metrics_path, final_score_column, k=200)
# Out:
# 84575189_0_6365692015941409487.csv
# metrics Time: 3.6917383670806885s
# 28086084_0_3127660530989916727.csv
# metrics Time: 8.609846115112305s
# 50270082_0_444360818941411589.csv
# metrics Time: 5.946252822875977s
# 29414811_2_4773219892816395776.csv
# metrics Time: 0.7568254470825195s
# 39759273_0_1427898308030295194.csv
# metrics Time: 3.6701691150665283s
# 14380604_4_3329235705746762392.csv
# metrics Time: 0.7795116901397705s
# 14067031_0_559833072073397908.csv
# metrics Time: 2.5387775897979736s
# 45073662_0_3179937335063201739.csv
# metrics Time: 1.0177044868469238s
# 52299421_0_4473286348258170200.csv
# metrics Time: 5.182516098022461s

# %%
metrics_df
# Out:
#      k        f1  precision    recall                                 tag
# 0  200  0.962963   0.928571  1.000000  84575189_0_6365692015941409487.csv
# 0  200  0.890932   0.831818  0.959091  28086084_0_3127660530989916727.csv
# 0  200  0.981818   0.964286  1.000000   50270082_0_444360818941411589.csv
# 0  200  0.926829   0.863636  1.000000  29414811_2_4773219892816395776.csv
# 0  200  0.994975   0.990000  1.000000  39759273_0_1427898308030295194.csv
# 0  200  0.950000   0.950000  0.950000  14380604_4_3329235705746762392.csv
# 0  200  0.943396   0.943396  0.943396   14067031_0_559833072073397908.csv
# 0  200  1.000000   1.000000  1.000000  45073662_0_3179937335063201739.csv
# 0  200  0.890110   0.890110  0.890110  52299421_0_4473286348258170200.csv

# %%
metrics_df['recall'].mean()
# Out:
# 0.971399669512877

# %%
metrics_df.to_csv(f"{dev_metrics_path}/metrics_200.csv", index=False)

# %%
metrics_df = compute_metrics(dev_predictions_top_k, dev_metrics_path, final_score_column, k=1)
# Out:
# 84575189_0_6365692015941409487.csv
# metrics Time: 3.7166073322296143s
# 28086084_0_3127660530989916727.csv
# metrics Time: 8.19441843032837s
# 50270082_0_444360818941411589.csv
# metrics Time: 5.905001401901245s
# 29414811_2_4773219892816395776.csv
# metrics Time: 0.7426278591156006s
# 39759273_0_1427898308030295194.csv
# metrics Time: 3.6778008937835693s
# 14380604_4_3329235705746762392.csv
# metrics Time: 0.7746427059173584s
# 14067031_0_559833072073397908.csv
# metrics Time: 2.4658446311950684s
# 45073662_0_3179937335063201739.csv
# metrics Time: 1.0018744468688965s
# 52299421_0_4473286348258170200.csv
# metrics Time: 4.926670551300049s

# %%
metrics_df
# Out:
#    k        f1  precision    recall                                 tag
# 0  1  0.928571   0.928571  0.928571  84575189_0_6365692015941409487.csv
# 0  1  0.831818   0.831818  0.831818  28086084_0_3127660530989916727.csv
# 0  1  0.964286   0.964286  0.964286   50270082_0_444360818941411589.csv
# 0  1  0.840295   0.863636  0.818182  29414811_2_4773219892816395776.csv
# 0  1  0.984975   0.990000  0.980000  39759273_0_1427898308030295194.csv
# 0  1  0.950000   0.950000  0.950000  14380604_4_3329235705746762392.csv
# 0  1  0.943396   0.943396  0.943396   14067031_0_559833072073397908.csv
# 0  1  1.000000   1.000000  1.000000  45073662_0_3179937335063201739.csv
# 0  1  0.884581   0.890110  0.879121  52299421_0_4473286348258170200.csv

# %%
metrics_df['f1'].mean()
# Out:
# 0.9253246964362959

# %%
metrics_df.to_csv(f"{dev_metrics_path}/metrics_1.csv", index=False)

# %%
add_color(dev_predictions_top_k, dev_colorized_path, final_score_column)
# Out:
# 84575189_0_6365692015941409487.csv
# add-color Time: 1.8227787017822266s
# 28086084_0_3127660530989916727.csv
# add-color Time: 3.9826228618621826s
# 50270082_0_444360818941411589.csv
# add-color Time: 2.8458807468414307s
# 29414811_2_4773219892816395776.csv
# add-color Time: 0.360825777053833s
# 39759273_0_1427898308030295194.csv
# add-color Time: 1.7265467643737793s
# 14380604_4_3329235705746762392.csv
# add-color Time: 0.35480785369873047s
# 14067031_0_559833072073397908.csv
# add-color Time: 1.1504685878753662s
# 45073662_0_3179937335063201739.csv
# add-color Time: 0.4418649673461914s
# 52299421_0_4473286348258170200.csv
# add-color Time: 2.371635675430298s
